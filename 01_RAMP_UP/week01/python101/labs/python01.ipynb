# %% [markdown]
# # Head 1
# ## Head 2
# ### Head 3
# #### Head 4
# ##### Head 5

# %% [markdown]
# # Programación Python 101
#
# ## Semana 1 - Matando el bicho
#
# ![matando el bicho](../img/python.jpg)

# %% [markdown]
# Ejemplo de código Python
#
# ```{python}
# <nombre_funcion>(cadena de texto o variables)
#
# print("Hello!")
# ```
#
# ***
#
# ALT+ENTER ejecuta la celda + crea una celda nueva </br>
# CTRL+ENTER ejecuta la celda
#
#
# ***
# > Ejemplo de LaTex en Markdown
#
# $
# % New definition of square root:
# % it renames \sqrt as \oldsqrt
# \let\oldsqrt\sqrt
# % it defines the new \sqrt in terms of the old one
# \def\sqrt{\mathpalette\DHLhksqrt}
# \def\DHLhksqrt#1#2{%
# \setbox0=\hbox{$#1\oldsqrt{#2\,}$}\dimen0=\ht0
# \advance\dimen0-0.2\ht0
# \setbox2=\hbox{\vrule height\ht0 depth -\dimen0}%
# {\box0\lower0.4pt\box2}}
# $

# %%
# Creamos la primera línea de código
print("Hello1")
print("Hello2")
# Out:
# Hello1
# Hello2

# %%
print()

# %%
PRINT()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\mrusso\OneDrive - ATSISTEMAS SA\Documentos\GitHub\TheBridge_DataScience_PT_ALUMNI_sep22\01_RAMP_UP\week01\python101\labs\python01.ipynb Celda 6 in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/mrusso/OneDrive%20-%20ATSISTEMAS%20SA/Documentos/GitHub/TheBridge_DataScience_PT_ALUMNI_sep22/01_RAMP_UP/week01/python101/labs/python01.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> PRINT()
#
# NameError: name 'PRINT' is not defined

# %%
print(1)
# Out:
# 1

# %%
ciudad = 'Madrid'
print(ciudad)
# Out:
# Madrid

# %%
# No son buenos ejemplos de nombrado de variable
CIUDAD = 'Barcelona'
Ciudad = 'Valencia'
Ciudades-de-España = 'Bilbao'
# Out:
#   Input In [12]
#     Ciudades-de-España = 'Bilbao'
#     ^
# SyntaxError: cannot assign to operator

# %%
# Ejemplos de variables
ciudades_de_espanya = 'Malaga'
ciudadesEspanya = 'Zaragoza'

# %%
# Quiero reutilizar una variable
print(ciudades_de_espanya)
# Out:
# Malaga

# %%
ciudades_de_espanya
# Out:
# 'Malaga'

# %%
type(ciudades_de_espanya)
# Out:
# str

# %%
anyo = 2022
type(anyo)
# Out:
# int

# %%
# Evitemos de crear variables con nombre de funciones nativas (built-in)
bool = True
str = 'Marco'

# %%
var_bool = False
type(var_bool)
# Out:
# bool

# %%
valor_dec = 10.5
type(valor_dec)
# Out:
# float

# %%
valor_dec = .5 # sustiye 0.5
print(type(valor_dec)) # funciones anidadas
valor_dec
# Out:
# <class 'float'>
# 0.5

# %%
valores_nulos = None
valores_nulos
print(type(valores_nulos))
# Out:
# <class 'NoneType'>

# %% [markdown]
# ## Creación de objetos en Python
# - listas ---- list() o []
# - diccionarios --- dict() o {key:value}
# - tuplas ---
# - set ---

# %% [markdown]
# ### List - Listas
#
# https://docs.python.org/3.9/tutorial/datastructures.html
#
#
# Son objetos que almacen valores del mismo tipo o diferente
#
# Tienen nombre similares: arreglos, listas, arrays, vectores
#
# ```
# list()
#
# nombre_variable_lista = []
#
# lista_valores = [1, 5., True, "Texto", None]
# ```

# %%
# Creamos el primer objeto lista
lista_valores = [5, .6, False, "Cadena de Texto", None]
type(lista_valores)
# Out:
# list

# %%
# Creación de un objeto del tipo lista con variables
anyos = [2020, 2021, 2022]
anyos
# Out:
# [2020, 2021, 2022]

# %%
type(anyos)
# Out:
# list

# %% [markdown]
# Las listas son objetos mutables, pueden transformarse, cambiar de tipo y nombre

# %%
anyo = 2023
anyos = anyo # cambiamos el tipo de objeto de lista a un entero

# %%
anyo
# Out:
# 2023

# %%
type(anyos)
# Out:
# int

# %% [markdown]
# > Como declaramos las listas

# %%
lista_ejemplo = list()
print(lista_ejemplo)
print(type(lista_ejemplo))
# Out:
# []
# <class 'list'>

# %%
lista_ejemplo_2 = []
print(lista_ejemplo_2)
print(type(lista_ejemplo_2))
# Out:
# []
# <class 'list'>

# %%
lista_ejemplo_2 == lista_ejemplo
# Out:
# True

# %%
lista_ejemplo > lista_ejemplo_2
# Out:
# False

# %%
edades = [21, 33, 40, 26, 36, 41]
edades
# Out:
# [21, 33, 40, 26, 36, 41]

# %%
# len() mide la longitud de un objeto
len(edades)
# Out:
# 6

# %%
estudiantes = ['Marta', 'Pepe', 'Lucas', 'Isabel', 'Lucia']
estudiantes
# Out:
# ['Marta', 'Pepe', 'Lucas', 'Isabel', 'Lucia']

# %%
len(estudiantes)
# Out:
# 5

# %%
estudiantes > edades
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\mrusso\OneDrive - ATSISTEMAS SA\Documentos\GitHub\TheBridge_DataScience_PT_ALUMNI_sep22\01_RAMP_UP\week01\python101\labs\python01.ipynb Celda 38 in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/mrusso/OneDrive%20-%20ATSISTEMAS%20SA/Documentos/GitHub/TheBridge_DataScience_PT_ALUMNI_sep22/01_RAMP_UP/week01/python101/labs/python01.ipynb#X61sZmlsZQ%3D%3D?line=0'>1</a> estudiantes > edades
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
estudiantes == edades
# Out:
# False

# %%
estudiantes
# Out:
# ['Marta', 'Pepe', 'Lucas', 'Isabel', 'Lucia']

# %%
estudiantes[4] #indicamos el índice 4 devolverá la posición 5
# Out:
# 'Lucia'

# %%
estudiantes[-1]
# Out:
# 'Lucia'

# %%
estudiantes[-5] == estudiantes[0] # es siempre el mismo elemento 'Marta'
estudiantes[0]
# Out:
# 'Marta'

# %%
type(estudiantes[3]) # devovlerá el tipo de elemento al índice 3 de esta lista
# Out:
# str

# %%
print(type(lista_valores[4]))
lista_valores
# Out:
# <class 'NoneType'>
# [5, 0.6, False, 'Cadena de Texto', None]

# %%
lista_valores[5] # devuelve un error tipo índice fuera del rango 0 a 4
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\mrusso\OneDrive - ATSISTEMAS SA\Documentos\GitHub\TheBridge_DataScience_PT_ALUMNI_sep22\01_RAMP_UP\week01\python101\labs\python01.ipynb Celda 46 in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/mrusso/OneDrive%20-%20ATSISTEMAS%20SA/Documentos/GitHub/TheBridge_DataScience_PT_ALUMNI_sep22/01_RAMP_UP/week01/python101/labs/python01.ipynb#Y102sZmlsZQ%3D%3D?line=0'>1</a> lista_valores[5]
#
# IndexError: list index out of range

# %%
print(len(edades))
print(len(estudiantes))
# Out:
# 6
# 5

# %%
# Añadimos un elemento a la lista
estudiantes.append('Juan')
estudiantes
# Out:
# ['Marta', 'Pepe', 'Lucas', 'Isabel', 'Lucia', 'Juan']

# %%
# Eliminar un elemento
estudiantes.pop()
estudiantes
# Out:
# ['Marta', 'Pepe', 'Lucas', 'Isabel', 'Lucia']

# %%
estudiantes.append('Jorge')
estudiantes # Una lista puede incluir elementos del mismo tipo y valor
# Out:
# ['Marta', 'Pepe', 'Lucas', 'Isabel', 'Lucia', 'Jorge', 'Jorge', 'Jorge']

# %%
estudiantes.pop()
estudiantes
# Out:
# ['Marta', 'Pepe', 'Lucas', 'Isabel', 'Lucia', 'Jorge']

# %%
# Utilizar el slice o recorrer una lista
estudiantes[0:2] # rango de índice 0 a 2 excepto el último
# Out:
# ['Marta', 'Pepe']

# %%
# Equivalente
estudiantes[:2]
# Out:
# ['Marta', 'Pepe']

# %% [markdown]
# ```
# <objeto_lista>[indexStart:indexEnd-1]
#
# ```

# %%
estudiantes[:-2]
# Out:
# ['Marta', 'Pepe', 'Lucas', 'Isabel', 'Lucia', 'Jorge']

# %%
estudiantes[::2]
# Out:
# ['Marta', 'Lucas', 'Lucia', 'Jorge']

# %%
estudiantes
# Out:
# ['Marta', 'Pepe', 'Lucas', 'Isabel', 'Lucia', 'Jorge', 'Jorge', 'Jorge']

# %%
estudiantes[::1]
# Out:
# ['Marta', 'Pepe', 'Lucas', 'Isabel', 'Lucia', 'Jorge', 'Jorge', 'Jorge']

# %%
estudiantes[::3]
# Out:
# ['Marta', 'Isabel', 'Jorge']

# %%
'Marta' in estudiantes
# Out:
# True

# %%
'Lucas' not in estudiantes
# Out:
# False

# %%
# Iterando con una lista
for name in estudiantes:
    print(name)
# Out:
# Marta
# Pepe
# Lucas
# Isabel
# Lucia
# Jorge
# Jorge
# Jorge

# %%
estudiantes * 3
# Out:
# ['Marta',
#  'Pepe',
#  'Lucas',
#  'Isabel',
#  'Lucia',
#  'Jorge',
#  'Jorge',
#  'Jorge',
#  'Marta',
#  'Pepe',
#  'Lucas',
#  'Isabel',
#  'Lucia',
#  'Jorge',
#  'Jorge',
#  'Jorge',
#  'Marta',
#  'Pepe',
#  'Lucas',
#  'Isabel',
#  'Lucia',
#  'Jorge',
#  'Jorge',
#  'Jorge']

# %%
estudiantes + estudiantes
# Out:
# ['Marta',
#  'Pepe',
#  'Lucas',
#  'Isabel',
#  'Lucia',
#  'Jorge',
#  'Jorge',
#  'Jorge',
#  'Marta',
#  'Pepe',
#  'Lucas',
#  'Isabel',
#  'Lucia',
#  'Jorge',
#  'Jorge',
#  'Jorge']

# %%
edades
# Out:
# [21, 33, 40, 26, 36, 41]

# %%
# Ordenar una lista
edades.sort()

# %%
edades
# Out:
# [21, 26, 33, 36, 40, 41]

# %%
edades.sort(reverse=True)
edades
# Out:
# [41, 40, 36, 33, 26, 21]

# %%
edades
# Out:
# [41, 40, 36, 33, 26, 21]

# %%
min(edades)
# Out:
# 21

# %%
max(edades)
# Out:
# 41

# %%
estudiantes
# Out:
# ['Marta', 'Pepe', 'Lucas', 'Isabel', 'Lucia', 'Jorge', 'Jorge', 'Jorge']

# %%
max(estudiantes)
# Out:
# 'Pepe'

# %%
min(estudiantes)
# Out:
# 'Isabel'

# %%
frase = 'Hoy es sábado, cuarto día del bootcamp The Bridge'
frase
# Out:
# 'Hoy es sábado, cuarto día del bootcamp The Bridge'

# %%
type(frase)
# Out:
# str

# %%
frase.split() # operación on fly - remover los espacios
# Out:
# ['Hoy', 'es', 'sábado,', 'cuarto', 'día', 'del', 'bootcamp', 'The', 'Bridge']

# %%
lista_words = frase.split()
type(lista_words)
# Out:
# list

# %%
frase
# Out:
# 'Hoy es sábado, cuarto día del bootcamp The Bridge'

# %%
frase.lower()
# Out:
# 'hoy es sábado, cuarto día del bootcamp the bridge'

# %%
lista_words
# Out:
# ['Hoy', 'es', 'sábado,', 'cuarto', 'día', 'del', 'bootcamp', 'The', 'Bridge']

# %%
lista_words.lower()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\mrusso\OneDrive - ATSISTEMAS SA\Documentos\GitHub\TheBridge_DataScience_PT_ALUMNI_sep22\01_RAMP_UP\week01\python101\labs\python01.ipynb Celda 82 in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/mrusso/OneDrive%20-%20ATSISTEMAS%20SA/Documentos/GitHub/TheBridge_DataScience_PT_ALUMNI_sep22/01_RAMP_UP/week01/python101/labs/python01.ipynb#Y153sZmlsZQ%3D%3D?line=0'>1</a> lista_words.lower()
#
# AttributeError: 'list' object has no attribute 'lower'

# %%
lista_words[:4].lower()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\mrusso\OneDrive - ATSISTEMAS SA\Documentos\GitHub\TheBridge_DataScience_PT_ALUMNI_sep22\01_RAMP_UP\week01\python101\labs\python01.ipynb Celda 83 in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/mrusso/OneDrive%20-%20ATSISTEMAS%20SA/Documentos/GitHub/TheBridge_DataScience_PT_ALUMNI_sep22/01_RAMP_UP/week01/python101/labs/python01.ipynb#Y154sZmlsZQ%3D%3D?line=0'>1</a> lista_words[:4].lower()
#
# AttributeError: 'list' object has no attribute 'lower'

# %%
lista_words
# Out:
# ['Hoy', 'es', 'sábado,', 'cuarto', 'día', 'del', 'bootcamp', 'The', 'Bridge']

# %%
# Volvemos a recuperar la frase original
' '.join(lista_words)
# Out:
# 'Hoy es sábado, cuarto día del bootcamp The Bridge'

# %%
nueva_frase = '&&'.join(lista_words)
nueva_frase
# Out:
# 'Hoy&&es&&sábado,&&cuarto&&día&&del&&bootcamp&&The&&Bridge'

# %%
nueva_frase.split(sep="&&") # utilizamos el separador '&&'
# Out:
# ['Hoy', 'es', 'sábado,', 'cuarto', 'día', 'del', 'bootcamp', 'The', 'Bridge']

# %%
# Creamos listas anidadas
lista_anidadas = [estudiantes, edades]
lista_anidadas
# Out:
# [['Marta', 'Pepe', 'Lucas', 'Isabel', 'Lucia', 'Jorge', 'Jorge', 'Jorge'],
#  [41, 40, 36, 33, 26, 21]]

# %%
type(lista_anidadas)
# Out:
# list

# %%
lista_anidadas[0][0]
# Out:
# 'Marta'

# %% [markdown]
# ## Control de flujos
#
# - for (iteraciones)
# - while
# - if...elif...else
