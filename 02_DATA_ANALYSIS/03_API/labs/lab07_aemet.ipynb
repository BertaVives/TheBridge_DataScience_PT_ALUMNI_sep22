# %% [markdown]
# # Lab 07
#
# La Agencia Estatal de meteorología (AEMET) es una agencia estatal, cuyo objetivo básico es la prestación de servicios meteorológicos, que sean competencia del Estado. Esta ofrece un sistema de datos abiertos (open data) para la difusión y reutilización de la información registrada y de la que dispone. A este conjunto de datos se puede acceder mediante la API AEMET OpenData que han desarrollado.
#
# Para la realización de este ejercicio, el alumno deberá previamente:
#
# Obtener la KEY que le permita hacer peticiones a la API (https://opendata.aemet.es/centrodedescargas/altaUsuario?)
#
# Revisar la sintaxi de Python que requiere la API (https://opendata.aemet.es/centrodedescargas/ejemProgramas?)
#
# Revisar la documentación o referencias de la API para observar cómo construir las peticiones (https://opendata.aemet.es/dist/index.html?#/)

# %% [markdown]
# Una vez tenidas en cuenta las anteriores consideraciones, se solicita al alumno que realice los siguientes puntos:
#
# 1. Obtener el inventario de todas las estaciones (En la documentación está referido dentro de _Valores Climatológicos_, _Inventario de estaciones_)
#
# 2. Obtener en un único DataFrame los valores de climatologías diarias del periodo comprendido entre 2022-09-01T00:00:00 UTC y 2022-09-08T00:00:00 UTC, de las cuatro estaciones cuyo nombre aparece en el inventario como: "BARCELONA AEROPUERTO", "ASTURIAS AEROPUERTO", "SEVILLA AEROPUERTO", "TENERIFE NORTE AEROPUERTO".
# > NOTA: Tened en cuenta que en la sintaxis de la solicitud hay que indicar el indicativo de la estación en lugar del nombre. Por tanto, tenéis que recorrer el resultado de la solicitud anterior y crear una lista con el valor del indicativo correspondiente a cada una de las cuatro estaciones solicitadas. Para ello, se recomienda convertir el json del resultado a dataframe.
#
# 3. Con el resultado de la petición anterior, crear cuatro dataframes diferentes (uno para cada estación), donde cada columna se corresponda con los campos que ofrece el resultado (fecha, indicativo, nombre,...) y cada fila con un registro o instancia diferente de la estación en cuestión.
#
# 4. Obtener dos mapas de incendio para las tres áreas (Península, Baleares y Canarias). El primer mapa hace referencia al último mapa disponible en el día que se realiza la actividad); el segundo es el relativo a la predicción para dentro de 2 días, considerando el día actual como el día que el estudiante realiza la actividad.

# %% [markdown]
# Una vez tenidas en cuenta las anteriores consideraciones, se solicita al alumno que realice los siguientes puntos:
#
# Obtener el inventario de todas las estaciones (En la documentación está referido dentro de Valores Climatológicos, Inventario de estaciones)
#
# Obtener en un único DataFrame los valores de climatologías diarias del periodo comprendido entre 2022-09-01T00:00:00 UTC y 2022-09-08T00:00:00 UTC, de las cuatro estaciones cuyo nombre aparece en el inventario como: "BARCELONA AEROPUERTO", "ASTURIAS AEROPUERTO", "SEVILLA AEROPUERTO", "TENERIFE NORTE AEROPUERTO".
#
# NOTA: Tened en cuenta que en la sintaxis de la solicitud hay que indicar el indicativo de la estación en lugar del nombre. Por tanto, tenéis que recorrer el resultado de la solicitud anterior y crear una lista con el valor del indicativo correspondiente a cada una de las cuatro estaciones solicitadas. Para ello, se recomienda convertir el json del resultado a dataframe.
#
# Con el resultado de la petición anterior, crear cuatro dataframes diferentes (uno para cada estación), donde cada columna se corresponda con los campos que ofrece el resultado (fecha, indicativo, nombre,...) y cada fila con un registro o instancia diferente de la estación en cuestión.
#
# Obtener dos mapas de incendio para las tres áreas (Península, Baleares y Canarias). El primer mapa hace referencia al último mapa disponible en el día que se realiza la actividad); el segundo es el relativo a la predicción para dentro de 2 días, considerando el día actual como el día que el estudiante realiza la actividad.

# %% [markdown]
# Ejemplo fichero credenciales creds.py
#
# ```
# aemet_key = {
#     'api_key' :  <TOKEN API KEY>
# }
#
# ```

# %%
# Cargar librerías
import requests
import time

import creds
import pandas as pd

# %%
# url
url = 'https://opendata.aemet.es/opendata/api/valores/climatologicos/inventarioestaciones/todasestaciones'
headers = {
    'cache-control' : 'no-cache'
}

querystring = {
    'api_key' : creds.creds_aemet.get('api_key')
}

# Creamos la solicitud

response = requests.request('GET', url, headers=headers, params=querystring)
print("La respuesta de la solicitud es {}. \n ".format(response.status_code))

print(response.text)
# Out:
# La respuesta de la solicitud es 200.
#
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/975cae05",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/0556af7a"
# }

# %%
response.json()
# Out:
# {'descripcion': 'exito',
#  'estado': 200,
#  'datos': 'https://opendata.aemet.es/opendata/sh/975cae05',
#  'metadatos': 'https://opendata.aemet.es/opendata/sh/0556af7a'}

# %%
response_data = requests.get(response.json()['datos'], verify=False) # response.json().get('datos')
response_data.json()
# Out:
# c:\Users\mrusso\Miniconda3\envs\the_bridge_22\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'opendata.aemet.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# [{'latitud': '413515N',
#   'provincia': 'BARCELONA',
#   'altitud': '74',
#   'indicativo': '0252D',
#   'nombre': 'ARENYS DE MAR',
#   'indsinop': '08186',
#   'longitud': '023224E'},
#  {'latitud': '411734N',
#   'provincia': 'BARCELONA',
#   'altitud': '4',
#   'indicativo': '0076',
#   'nombre': 'BARCELONA AEROPUERTO',
#   'indsinop': '08181',
#   'longitud': '020412E'},
#  {'latitud': '412506N',
#   'provincia': 'BARCELONA',
#   'altitud': '408',
#   'indicativo': '0200E',
#   'nombre': 'BARCELONA, FABRA',
#   'indsinop': '',
#   'longitud': '020727E'},
#  {'latitud': '412326N',
#   'provincia': 'BARCELONA',
#   'altitud': '6',
#   'indicativo': '0201D',
#   'nombre': 'BARCELONA',
#   'indsinop': '08180',
#   'longitud': '021200E'},
#  {'latitud': '414312N',
#   'provincia': 'BARCELONA',
#   'altitud': '291',
#   'indicativo': '0149X',
#   'nombre': 'MANRESA',
#   'indsinop': '08174',
#   'longitud': '015025E'},
#  {'latitud': '413125N',
#   'provincia': 'BARCELONA',
#   'altitud': '146',
#   'indicativo': '0229I',
#   'nombre': 'SABADELL AEROPUERTO',
#   'indsinop': '08192',
#   'longitud': '020611E'},
#  {'latitud': '413903N',
#   'provincia': 'BARCELONA',
#   'altitud': '40',
#   'indicativo': '0255B',
#   'nombre': 'SANTA SUSANNA',
#   'indsinop': '08188',
#   'longitud': '024149E'},
#  {'latitud': '415442N',
#   'provincia': 'GIRONA',
#   'altitud': '143',
#   'indicativo': '0367',
#   'nombre': 'GIRONA AEROPUERTO',
#   'indsinop': '08184',
#   'longitud': '024548E'},
#  {'latitud': '415848N',
#   'provincia': 'GIRONA',
#   'altitud': '95',
#   'indicativo': '0370B',
#   'nombre': 'GIRONA, ANTIC INSTITUT',
#   'indsinop': '',
#   'longitud': '024931E'},
#  {'latitud': '420616N',
#   'provincia': 'GIRONA',
#   'altitud': '157',
#   'indicativo': '0372C',
#   'nombre': 'PORQUERES',
#   'indsinop': '08120',
#   'longitud': '024549E'},
#  {'latitud': '421129N',
#   'provincia': 'GIRONA',
#   'altitud': '675',
#   'indicativo': '0324A',
#   'nombre': 'RIPOLL',
#   'indsinop': '08118',
#   'longitud': '021146E'},
#  {'latitud': '410842N',
#   'provincia': 'TARRAGONA',
#   'altitud': '71',
#   'indicativo': '0016A',
#   'nombre': 'REUS AEROPUERTO',
#   'indsinop': '08175',
#   'longitud': '010949E'},
#  {'latitud': '405729N',
#   'provincia': 'TARRAGONA',
#   'altitud': '32',
#   'indicativo': '0002I',
#   'nombre': 'VANDELLÒS  ',
#   'indsinop': '08169',
#   'longitud': '005217E'},
#  {'latitud': '431825N',
#   'provincia': 'A CORUÑA',
#   'altitud': '98',
#   'indicativo': '1387E',
#   'nombre': 'A CORUÑA AEROPUERTO',
#   'indsinop': '08002',
#   'longitud': '082219W'},
#  {'latitud': '432157N',
#   'provincia': 'A CORUÑA',
#   'altitud': '58',
#   'indicativo': '1387',
#   'nombre': 'A CORUÑA',
#   'indsinop': '08001',
#   'longitud': '082517W'},
#  {'latitud': '430938N',
#   'provincia': 'A CORUÑA',
#   'altitud': '50',
#   'indicativo': '1393',
#   'nombre': 'CABO VILÁN',
#   'indsinop': '08006',
#   'longitud': '091239W'},
#  {'latitud': '434710N',
#   'provincia': 'A CORUÑA',
#   'altitud': '90',
#   'indicativo': '1351',
#   'nombre': 'ESTACA DE BARES',
#   'indsinop': '08004',
#   'longitud': '074106W'},
#  {'latitud': '425529N',
#   'provincia': 'A CORUÑA',
#   'altitud': '230',
#   'indicativo': '1400',
#   'nombre': 'FISTERRA',
#   'indsinop': '08040',
#   'longitud': '091729W'},
#  {'latitud': '424314N',
#   'provincia': 'A CORUÑA',
#   'altitud': '685',
#   'indicativo': '1437O',
#   'nombre': 'MONTE IROITE',
#   'indsinop': '08043',
#   'longitud': '085524W'},
#  {'latitud': '424418N',
#   'provincia': 'A CORUÑA',
#   'altitud': '100',
#   'indicativo': '1473A',
#   'nombre': 'PADRÓN',
#   'indsinop': '08039',
#   'longitud': '083738W'},
#  {'latitud': '425317N',
#   'provincia': 'A CORUÑA',
#   'altitud': '370',
#   'indicativo': '1428',
#   'nombre': 'SANTIAGO DE COMPOSTELA AEROPUERTO',
#   'indsinop': '08042',
#   'longitud': '082438W'},
#  {'latitud': '425234N',
#   'provincia': 'A CORUÑA',
#   'altitud': '240',
#   'indicativo': '1475X',
#   'nombre': 'SANTIAGO DE COMPOSTELA',
#   'indsinop': '08041',
#   'longitud': '083321W'},
#  {'latitud': '433401N',
#   'provincia': 'ASTURIAS',
#   'altitud': '127',
#   'indicativo': '1212E',
#   'nombre': 'ASTURIAS AEROPUERTO',
#   'indsinop': '08011',
#   'longitud': '060239W'},
#  {'latitud': '433409N',
#   'provincia': 'ASTURIAS',
#   'altitud': '60',
#   'indicativo': '1283U',
#   'nombre': 'CABO BUSTO',
#   'indsinop': '08010',
#   'longitud': '062812W'},
#  {'latitud': '433921N',
#   'provincia': 'ASTURIAS',
#   'altitud': '100',
#   'indicativo': '1210X',
#   'nombre': 'CABO PEÑAS',
#   'indsinop': '08012',
#   'longitud': '055055W'},
#  {'latitud': '433129N',
#   'provincia': 'ASTURIAS',
#   'altitud': '40',
#   'indicativo': '1331A',
#   'nombre': 'CASTROPOL',
#   'indsinop': '08009',
#   'longitud': '070153W'},
#  {'latitud': '433123N',
#   'provincia': 'ASTURIAS',
#   'altitud': '26',
#   'indicativo': '1207U',
#   'nombre': 'GIJÓN, CAMPUS',
#   'indsinop': '08014',
#   'longitud': '053716W'},
#  {'latitud': '433230N',
#   'provincia': 'ASTURIAS',
#   'altitud': '22',
#   'indicativo': '1208A',
#   'nombre': 'GIJÓN. LA MERCED',
#   'indsinop': '',
#   'longitud': '053943W'},
#  {'latitud': '433336N',
#   'provincia': 'ASTURIAS',
#   'altitud': '5',
#   'indicativo': '1208H',
#   'nombre': 'GIJÓN, PUERTO',
#   'indsinop': '08014',
#   'longitud': '054203W'},
#  {'latitud': '433220N',
#   'provincia': 'ASTURIAS',
#   'altitud': '3',
#   'indicativo': '1208',
#   'nombre': 'GIJÓN',
#   'indsinop': '',
#   'longitud': '053815W'},
#  {'latitud': '432513N',
#   'provincia': 'ASTURIAS',
#   'altitud': '10',
#   'indicativo': '1183X',
#   'nombre': 'LLANES',
#   'indsinop': '08016',
#   'longitud': '044453W'},
#  {'latitud': '432112N',
#   'provincia': 'ASTURIAS',
#   'altitud': '336',
#   'indicativo': '1249I',
#   'nombre': 'OVIEDO',
#   'indsinop': '08015',
#   'longitud': '055227W'},
#  {'latitud': '432112N',
#   'provincia': 'ASTURIAS',
#   'altitud': '336',
#   'indicativo': '1249X',
#   'nombre': 'OVIEDO',
#   'indsinop': '08015',
#   'longitud': '055227W'},
#  {'latitud': '425843N',
#   'provincia': 'ASTURIAS',
#   'altitud': '1480',
#   'indicativo': '1221D',
#   'nombre': 'PAJARES-VALGRANDE',
#   'indsinop': '08031',
#   'longitud': '054635W'},
#  {'latitud': '425939N',
#   'provincia': 'ASTURIAS',
#   'altitud': '1530',
#   'indicativo': '1542',
#   'nombre': 'PUERTO DE LEITARIEGOS',
#   'indsinop': '08052',
#   'longitud': '062451W'},
#  {'latitud': '431753N',
#   'provincia': 'BIZKAIA',
#   'altitud': '42',
#   'indicativo': '1082',
#   'nombre': 'BILBAO AEROPUERTO',
#   'indsinop': '08025',
#   'longitud': '025423W'},
#  {'latitud': '431212N',
#   'provincia': 'BIZKAIA',
#   'altitud': '208',
#   'indicativo': '1078I',
#   'nombre': 'GÜEÑES',
#   'indsinop': '08035',
#   'longitud': '030617W'},
#  {'latitud': '432237N',
#   'provincia': 'BIZKAIA',
#   'altitud': '12',
#   'indicativo': '1055B',
#   'nombre': 'LEKEITIO',
#   'indsinop': '08024',
#   'longitud': '023037W'},
#  {'latitud': '432714N',
#   'provincia': 'BIZKAIA',
#   'altitud': '93',
#   'indicativo': '1057B',
#   'nombre': 'MACHICHACO',
#   'indsinop': '',
#   'longitud': '024510W'},
#  {'latitud': '432230N',
#   'provincia': 'BIZKAIA',
#   'altitud': '90',
#   'indicativo': '1059X',
#   'nombre': 'PUNTA GALEA',
#   'indsinop': '08059',
#   'longitud': '030118W'},
#  {'latitud': '432341N',
#   'provincia': 'CANTABRIA',
#   'altitud': '45',
#   'indicativo': '1083L',
#   'nombre': 'CASTRO URDIALES',
#   'indsinop': '08020',
#   'longitud': '031402W'},
#  {'latitud': '432336N',
#   'provincia': 'CANTABRIA',
#   'altitud': '38',
#   'indicativo': '1159',
#   'nombre': 'SAN VICENTE DE LA BARQUERA',
#   'indsinop': '08017',
#   'longitud': '042332W'},
#  {'latitud': '432526N',
#   'provincia': 'CANTABRIA',
#   'altitud': '3',
#   'indicativo': '1109',
#   'nombre': 'SANTANDER AEROPUERTO',
#   'indsinop': '08021',
#   'longitud': '034932W'},
#  {'latitud': '432754N',
#   'provincia': 'CANTABRIA',
#   'altitud': '64',
#   'indicativo': '1110',
#   'nombre': 'SANTANDER, CIUDAD',
#   'indsinop': '',
#   'longitud': '034908W'},
#  {'latitud': '432928N',
#   'provincia': 'CANTABRIA',
#   'altitud': '52',
#   'indicativo': '1111',
#   'nombre': 'SANTANDER',
#   'indsinop': '08023',
#   'longitud': '034802W'},
#  {'latitud': '432928N',
#   'provincia': 'CANTABRIA',
#   'altitud': '52',
#   'indicativo': '1111X',
#   'nombre': 'SANTANDER',
#   'indsinop': '08023',
#   'longitud': '034802W'},
#  {'latitud': '431823N',
#   'provincia': 'GIPUZKOA',
#   'altitud': '251',
#   'indicativo': '1024E',
#   'nombre': 'DONOSTIA/SAN SEBASTIÁN, IGUELDO',
#   'indsinop': '08027',
#   'longitud': '020228W'},
#  {'latitud': '431234N',
#   'provincia': 'GIPUZKOA',
#   'altitud': '119',
#   'indicativo': '1050J',
#   'nombre': 'ELGOIBAR',
#   'indsinop': '08036',
#   'longitud': '022448W'},
#  {'latitud': '432125N',
#   'provincia': 'GIPUZKOA',
#   'altitud': '4',
#   'indicativo': '1014',
#   'nombre': 'HONDARRIBIA, MALKARROA',
#   'indsinop': '08029',
#   'longitud': '014732W'},
#  {'latitud': '432125N',
#   'provincia': 'GIPUZKOA',
#   'altitud': '4',
#   'indicativo': '1014A',
#   'nombre': 'SAN SEBASTIÁN AEROPUERTO',
#   'indsinop': '08029',
#   'longitud': '014732W'},
#  {'latitud': '431808N',
#   'provincia': 'GIPUZKOA',
#   'altitud': '28',
#   'indicativo': '1041A',
#   'nombre': 'ZUMAIA',
#   'indsinop': '08026',
#   'longitud': '021504W'},
#  {'latitud': '430448N',
#   'provincia': 'GIPUZKOA',
#   'altitud': '420',
#   'indicativo': '1037Y',
#   'nombre': 'ZUMARRAGA',
#   'indsinop': '08037',
#   'longitud': '021903W'},
#  {'latitud': '423350N',
#   'provincia': 'LEON',
#   'altitud': '534',
#   'indicativo': '1549',
#   'nombre': 'PONFERRADA',
#   'indsinop': '08053',
#   'longitud': '063600W'},
#  {'latitud': '430641N',
#   'provincia': 'LUGO',
#   'altitud': '445',
#   'indicativo': '1505',
#   'nombre': 'LUGO AEROPUERTO',
#   'indsinop': '08008',
#   'longitud': '072727W'},
#  {'latitud': '430809N',
#   'provincia': 'NAVARRA',
#   'altitud': '183',
#   'indicativo': '1002Y',
#   'nombre': 'BAZTAN, IRURITA ',
#   'indsinop': '08030',
#   'longitud': '013235W'},
#  {'latitud': '422022N',
#   'provincia': 'OURENSE',
#   'altitud': '840',
#   'indicativo': '1631E',
#   'nombre': 'A POBRA DE TRIVES',
#   'indsinop': '08051',
#   'longitud': '071657W'},
#  {'latitud': '422517N',
#   'provincia': 'OURENSE',
#   'altitud': '400',
#   'indicativo': '1700X',
#   'nombre': 'O CARBALLIÑO',
#   'indsinop': '08047',
#   'longitud': '080533W'},
#  {'latitud': '421956N',
#   'provincia': 'OURENSE',
#   'altitud': '148',
#   'indicativo': '1690B',
#   'nombre': 'OURENSE,INSTITUTO',
#   'indsinop': '',
#   'longitud': '075152W'},
#  {'latitud': '421931N',
#   'provincia': 'OURENSE',
#   'altitud': '143',
#   'indicativo': '1690A',
#   'nombre': 'OURENSE',
#   'indsinop': '08048',
#   'longitud': '075135W'},
#  {'latitud': '420445N',
#   'provincia': 'OURENSE',
#   'altitud': '616',
#   'indicativo': '1735X',
#   'nombre': 'XINZO DE LIMIA',
#   'indsinop': '08050',
#   'longitud': '074401W'},
#  {'latitud': '422550N',
#   'provincia': 'PONTEVEDRA',
#   'altitud': '19',
#   'indicativo': '1484',
#   'nombre': 'PONTEVEDRA, INSTITUTO',
#   'indsinop': '',
#   'longitud': '083850W'},
#  {'latitud': '422618N',
#   'provincia': 'PONTEVEDRA',
#   'altitud': '108',
#   'indicativo': '1484C',
#   'nombre': 'PONTEVEDRA',
#   'indsinop': '08044',
#   'longitud': '083657W'},
#  {'latitud': '421419N',
#   'provincia': 'PONTEVEDRA',
#   'altitud': '261',
#   'indicativo': '1495',
#   'nombre': 'VIGO AEROPUERTO',
#   'indsinop': '08045',
#   'longitud': '083726W'},
#  {'latitud': '403924N',
#   'provincia': 'AVILA',
#   'altitud': '1143',
#   'indicativo': '2444C',
#   'nombre': 'ÁVILA, AYUNTAMIENTO',
#   'indsinop': '',
#   'longitud': '044201W'},
#  {'latitud': '403933N',
#   'provincia': 'AVILA',
#   'altitud': '1130',
#   'indicativo': '2444',
#   'nombre': 'ÁVILA',
#   'indsinop': '08210',
#   'longitud': '044048W'},
#  {'latitud': '402102N',
#   'provincia': 'AVILA',
#   'altitud': '1525',
#   'indicativo': '2811A',
#   'nombre': 'NAVARREDONDA DE GREDOS',
#   'indsinop': '08206',
#   'longitud': '050835W'},
#  {'latitud': '413957N',
#   'provincia': 'BURGOS',
#   'altitud': '790',
#   'indicativo': '2117D',
#   'nombre': 'ARANDA DE DUERO',
#   'indsinop': '08144',
#   'longitud': '034434W'},
#  {'latitud': '422125N',
#   'provincia': 'BURGOS',
#   'altitud': '891',
#   'indicativo': '2331',
#   'nombre': 'BURGOS AEROPUERTO',
#   'indsinop': '08075',
#   'longitud': '033713W'},
#  {'latitud': '415735N',
#   'provincia': 'BURGOS',
#   'altitud': '1080',
#   'indicativo': '2298',
#   'nombre': 'PALACIOS DE LA SIERRA',
#   'indsinop': '08149',
#   'longitud': '030754W'},
#  {'latitud': '422239N',
#   'provincia': 'LEON',
#   'altitud': '1020',
#   'indicativo': '2737E',
#   'nombre': 'LAGUNAS DE SOMOZA',
#   'indsinop': '08123',
#   'longitud': '061148W'},
#  {'latitud': '423558N',
#   'provincia': 'LEON',
#   'altitud': '912',
#   'indicativo': '2661B',
#   'nombre': 'LEÓN AEROPUERTO',
#   'indsinop': '08055',
#   'longitud': '053837W'},
#  {'latitud': '423518N',
#   'provincia': 'LEON',
#   'altitud': '912',
#   'indicativo': '2661',
#   'nombre': 'LEÓN, VIRGEN DEL CAMINO',
#   'indsinop': '08055',
#   'longitud': '053904W'},
#  {'latitud': '430344N',
#   'provincia': 'LEON',
#   'altitud': '1510',
#   'indicativo': '2630X',
#   'nombre': 'PUERTO DE SAN ISIDRO',
#   'indsinop': '08057',
#   'longitud': '052237W'},
#  {'latitud': '404735N',
#   'provincia': 'MADRID',
#   'altitud': '1894',
#   'indicativo': '2462',
#   'nombre': 'PUERTO DE NAVACERRADA',
#   'indsinop': '08215',
#   'longitud': '040038W'},
#  {'latitud': '415944N',
#   'provincia': 'PALENCIA',
#   'altitud': '874',
#   'indicativo': '2400E',
#   'nombre': 'AUTILLA DEL PINO',
#   'indsinop': '08072',
#   'longitud': '043610W'},
#  {'latitud': '422103N',
#   'provincia': 'PALENCIA',
#   'altitud': '830',
#   'indicativo': '2374X',
#   'nombre': 'CARRIÓN DE LOS CONDES',
#   'indsinop': '08068',
#   'longitud': '043702W'},
#  {'latitud': '425214N',
#   'provincia': 'PALENCIA',
#   'altitud': '1140',
#   'indicativo': '2235U',
#   'nombre': 'CERVERA DE PISUERGA',
#   'indsinop': '08058',
#   'longitud': '043112W'},
#  {'latitud': '420018N',
#   'provincia': 'PALENCIA',
#   'altitud': '750',
#   'indicativo': '2401',
#   'nombre': 'PALENCIA, OBSERVATORIO',
#   'indsinop': '',
#   'longitud': '043145W'},
#  {'latitud': '402118N',
#   'provincia': 'SALAMANCA',
#   'altitud': '1960',
#   'indicativo': '2491C',
#   'nombre': 'LA COVATILLA, ESTACIÓN DE ESQUÍ',
#   'indsinop': '08205',
#   'longitud': '054124W'},
#  {'latitud': '403806N',
#   'provincia': 'SALAMANCA',
#   'altitud': '680',
#   'indicativo': '2946X',
#   'nombre': 'SAELICES EL CHICO',
#   'indsinop': '08195',
#   'longitud': '063600W'},
#  {'latitud': '405734N',
#   'provincia': 'SALAMANCA',
#   'altitud': '790',
#   'indicativo': '2867',
#   'nombre': 'SALAMANCA AEROPUERTO',
#   'indsinop': '08202',
#   'longitud': '052954W'},
#  {'latitud': '405727N',
#   'provincia': 'SALAMANCA',
#   'altitud': '775',
#   'indicativo': '2870',
#   'nombre': 'SALAMANCA',
#   'indsinop': '08201',
#   'longitud': '053944W'},
#  {'latitud': '410041N',
#   'provincia': 'SALAMANCA',
#   'altitud': '769',
#   'indicativo': '2916A',
#   'nombre': 'VITIGUDINO',
#   'indsinop': '08129',
#   'longitud': '062616W'},
#  {'latitud': '411131N',
#   'provincia': 'SEGOVIA',
#   'altitud': '1798',
#   'indicativo': '2150H',
#   'nombre': 'LA PINILLA, ESTACIÓN DE ESQUÍ',
#   'indsinop': '08143',
#   'longitud': '032831W'},
#  {'latitud': '405648N',
#   'provincia': 'SEGOVIA',
#   'altitud': '990',
#   'indicativo': '2465A',
#   'nombre': 'SEGOVIA, INSTITUTO',
#   'indsinop': '',
#   'longitud': '040657W'},
#  {'latitud': '405643N',
#   'provincia': 'SEGOVIA',
#   'altitud': '1005',
#   'indicativo': '2465',
#   'nombre': 'SEGOVIA',
#   'indsinop': '08213',
#   'longitud': '040735W'},
#  {'latitud': '414630N',
#   'provincia': 'SORIA',
#   'altitud': '1082',
#   'indicativo': '2030',
#   'nombre': 'SORIA',
#   'indsinop': '08148',
#   'longitud': '022859W'},
#  {'latitud': '411933N',
#   'provincia': 'VALLADOLID',
#   'altitud': '740',
#   'indicativo': '2503X',
#   'nombre': 'OLMEDO',
#   'indsinop': '08142',
#   'longitud': '044113W'},
#  {'latitud': '414243N',
#   'provincia': 'VALLADOLID',
#   'altitud': '846',
#   'indicativo': '2539',
#   'nombre': 'VALLADOLID AEROPUERTO',
#   'indsinop': '08140',
#   'longitud': '045120W'},
#  {'latitud': '413827N',
#   'provincia': 'VALLADOLID',
#   'altitud': '735',
#   'indicativo': '2422',
#   'nombre': 'VALLADOLID',
#   'indsinop': '08141',
#   'longitud': '044516W'},
#  {'latitud': '420039N',
#   'provincia': 'ZAMORA',
#   'altitud': '715',
#   'indicativo': '2755X',
#   'nombre': 'BENAVENTE',
#   'indsinop': '08056',
#   'longitud': '054000W'},
#  {'latitud': '415629N',
#   'provincia': 'ZAMORA',
#   'altitud': '850',
#   'indicativo': '2775X',
#   'nombre': 'VILLARDECIERVOS',
#   'indsinop': '08125',
#   'longitud': '061647W'},
#  {'latitud': '413056N',
#   'provincia': 'ZAMORA',
#   'altitud': '656',
#   'indicativo': '2614',
#   'nombre': 'ZAMORA',
#   'indsinop': '08130',
#   'longitud': '054407W'},
#  {'latitud': '401719N',
#   'provincia': 'AVILA',
#   'altitud': '630',
#   'indicativo': '3391',
#   'nombre': 'SOTILLO DE LA ADRADA',
#   'indsinop': '08208',
#   'longitud': '043527W'},
#  {'latitud': '392833N',
#   'provincia': 'CACERES',
#   'altitud': '459',
#   'indicativo': '3469',
#   'nombre': 'CÁCERES, CIUDAD',
#   'indsinop': '',
#   'longitud': '062235W'},
#  {'latitud': '392817N',
#   'provincia': 'CACERES',
#   'altitud': '394',
#   'indicativo': '3469A',
#   'nombre': 'CÁCERES',
#   'indsinop': '08261',
#   'longitud': '062020W'},
#  {'latitud': '400013N',
#   'provincia': 'CACERES',
#   'altitud': '313',
#   'indicativo': '3526X',
#   'nombre': 'CORIA',
#   'indsinop': '08251',
#   'longitud': '063327W'},
#  {'latitud': '395645N',
#   'provincia': 'CACERES',
#   'altitud': '269',
#   'indicativo': '3434X',
#   'nombre': 'NAVALMORAL DE LA MATA',
#   'indsinop': '08254',
#   'longitud': '053457W'},
#  {'latitud': '400235N',
#   'provincia': 'CACERES',
#   'altitud': '415',
#   'indicativo': '3519X',
#   'nombre': 'PLASENCIA',
#   'indsinop': '08252',
#   'longitud': '060509W'},
#  {'latitud': '392857N',
#   'provincia': 'CACERES',
#   'altitud': '503',
#   'indicativo': '3463X',
#   'nombre': 'TRUJILLO',
#   'indsinop': '08263',
#   'longitud': '055115W'},
#  {'latitud': '392453N',
#   'provincia': 'CACERES',
#   'altitud': '444',
#   'indicativo': '3576X',
#   'nombre': 'VALENCIA DE ALCÁNTARA',
#   'indsinop': '08260',
#   'longitud': '071352W'},
#  {'latitud': '403149N',
#   'provincia': 'CUENCA',
#   'altitud': '928',
#   'indicativo': '3044X',
#   'nombre': 'CAÑIZARES',
#   'indsinop': '08230',
#   'longitud': '020900W'},
#  {'latitud': '400041N',
#   'provincia': 'CUENCA',
#   'altitud': '808',
#   'indicativo': '3094B',
#   'nombre': 'TARANCÓN',
#   'indsinop': '08277',
#   'longitud': '030117W'},
#  {'latitud': '403933N',
#   'provincia': 'GUADALAJARA',
#   'altitud': '639',
#   'indicativo': '3168C',
#   'nombre': 'GUADALAJARA, EL SERRANILLO',
#   'indsinop': '08226',
#   'longitud': '031024W'},
#  {'latitud': '403805N',
#   'provincia': 'GUADALAJARA',
#   'altitud': '685',
#   'indicativo': '3168A',
#   'nombre': 'GUADALAJARA, INSTITUTO',
#   'indsinop': '',
#   'longitud': '031000W'},
#  {'latitud': '403749N',
#   'provincia': 'GUADALAJARA',
#   'altitud': '721',
#   'indicativo': '3168D',
#   'nombre': 'GUADALAJARA',
#   'indsinop': '08226',
#   'longitud': '030900W'},
#  {'latitud': '405030N',
#   'provincia': 'GUADALAJARA',
#   'altitud': '1062',
#   'indicativo': '3013',
#   'nombre': 'MOLINA DE ARAGÓN',
#   'indsinop': '08232',
#   'longitud': '015244W'},
#  {'latitud': '410511N',
#   'provincia': 'GUADALAJARA',
#   'altitud': '1005',
#   'indicativo': '3130C',
#   'nombre': 'SIGÜENZA',
#   'indsinop': '08150',
#   'longitud': '023705W'},
#  {'latitud': '400402N',
#   'provincia': 'MADRID',
#   'altitud': '540',
#   'indicativo': '3100B',
#   'nombre': 'ARANJUEZ',
#   'indsinop': '08229',
#   'longitud': '033246W'},
#  {'latitud': '410025N',
#   'provincia': 'MADRID',
#   'altitud': '1030',
#   'indicativo': '3110C',
#   'nombre': 'BUITRAGO DEL LOZOYA',
#   'indsinop': '08146',
#   'longitud': '033649W'},
#  {'latitud': '404146N',
#   'provincia': 'MADRID',
#   'altitud': '1004',
#   'indicativo': '3191E',
#   'nombre': 'COLMENAR VIEJO',
#   'indsinop': '08219',
#   'longitud': '034554W'},
#  {'latitud': '401758N',
#   'provincia': 'MADRID',
#   'altitud': '620',
#   'indicativo': '3200',
#   'nombre': 'GETAFE',
#   'indsinop': '08224',
#   'longitud': '034320W'},
#  {'latitud': '402800N',
#   'provincia': 'MADRID',
#   'altitud': '609',
#   'indicativo': '3129',
#   'nombre': 'MADRID AEROPUERTO',
#   'indsinop': '08221',
#   'longitud': '033320W'},
#  {'latitud': '402706N',
#   'provincia': 'MADRID',
#   'altitud': '664',
#   'indicativo': '3194U',
#   'nombre': 'MADRID, CIUDAD UNIVERSITARIA',
#   'indsinop': '08220',
#   'longitud': '034327W'},
#  {'latitud': '402232N',
#   'provincia': 'MADRID',
#   'altitud': '690',
#   'indicativo': '3196',
#   'nombre': 'MADRID, CUATRO VIENTOS',
#   'indsinop': '08223',
#   'longitud': '034710W'},
#  {'latitud': '402443N',
#   'provincia': 'MADRID',
#   'altitud': '667',
#   'indicativo': '3195',
#   'nombre': 'MADRID, RETIRO',
#   'indsinop': '08222',
#   'longitud': '034041W'},
#  {'latitud': '404223N',
#   'provincia': 'MADRID',
#   'altitud': '1532',
#   'indicativo': '3266A',
#   'nombre': 'PUERTO ALTO DEL LEÓN',
#   'indsinop': '08217',
#   'longitud': '040831W'},
#  {'latitud': '402540N',
#   'provincia': 'MADRID',
#   'altitud': '763',
#   'indicativo': '3338',
#   'nombre': 'ROBLEDO DE CHAVELA',
#   'indsinop': '08212',
#   'longitud': '041500W'},
#  {'latitud': '410808N',
#   'provincia': 'MADRID',
#   'altitud': '1450',
#   'indicativo': '3111D',
#   'nombre': 'SOMOSIERRA',
#   'indsinop': '08145',
#   'longitud': '033449W'},
#  {'latitud': '402919N',
#   'provincia': 'MADRID',
#   'altitud': '607',
#   'indicativo': '3175',
#   'nombre': 'TORREJÓN DE ARDOZ',
#   'indsinop': '08227',
#   'longitud': '032637W'},
#  {'latitud': '393249N',
#   'provincia': 'TOLEDO',
#   'altitud': '917',
#   'indicativo': '3298X',
#   'nombre': 'SAN PABLO DE LOS MONTES',
#   'indsinop': '08270',
#   'longitud': '042102W'},
#  {'latitud': '395731N',
#   'provincia': 'TOLEDO',
#   'altitud': '372',
#   'indicativo': '3365A',
#   'nombre': 'TALAVERA DE LA REINA',
#   'indsinop': '08274',
#   'longitud': '045149W'},
#  {'latitud': '395134N',
#   'provincia': 'TOLEDO',
#   'altitud': '540',
#   'indicativo': '3259',
#   'nombre': 'TOLEDO, LORENZANA',
#   'indsinop': '',
#   'longitud': '040132W'},
#  {'latitud': '395305N',
#   'provincia': 'TOLEDO',
#   'altitud': '515',
#   'indicativo': '3260B',
#   'nombre': 'TOLEDO',
#   'indsinop': '08272',
#   'longitud': '040243W'},
#  {'latitud': '385300N',
#   'provincia': 'BADAJOZ',
#   'altitud': '185',
#   'indicativo': '4452',
#   'nombre': 'BADAJOZ AEROPUERTO',
#   'indsinop': '08330',
#   'longitud': '064850W'},
#  {'latitud': '385720N',
#   'provincia': 'BADAJOZ',
#   'altitud': '273',
#   'indicativo': '4358X',
#   'nombre': 'DON BENITO',
#   'indsinop': '08333',
#   'longitud': '055250W'},
#  {'latitud': '391010N',
#   'provincia': 'BADAJOZ',
#   'altitud': '447',
#   'indicativo': '4244X',
#   'nombre': 'HERRERA DEL DUQUE',
#   'indsinop': '08264',
#   'longitud': '050344W'},
#  {'latitud': '381755N',
#   'provincia': 'BADAJOZ',
#   'altitud': '381',
#   'indicativo': '4511C',
#   'nombre': 'JEREZ DE LOS CABALLEROS',
#   'indsinop': '08337',
#   'longitud': '064554W'},
#  {'latitud': '381354N',
#   'provincia': 'BADAJOZ',
#   'altitud': '655',
#   'indicativo': '4386B',
#   'nombre': 'LLERENA',
#   'indsinop': '08336',
#   'longitud': '060101W'},
#  {'latitud': '385457N',
#   'provincia': 'BADAJOZ',
#   'altitud': '228',
#   'indicativo': '4410X',
#   'nombre': 'MÉRIDA',
#   'indsinop': '08331',
#   'longitud': '062308W'},
#  {'latitud': '385916N',
#   'provincia': 'CIUDAD REAL',
#   'altitud': '627',
#   'indicativo': '4121C',
#   'nombre': 'CIUDAD REAL, INSTITUTO',
#   'indsinop': '',
#   'longitud': '035545W'},
#  {'latitud': '385921N',
#   'provincia': 'CIUDAD REAL',
#   'altitud': '628',
#   'indicativo': '4121',
#   'nombre': 'CIUDAD REAL',
#   'indsinop': '08348',
#   'longitud': '035513W'},
#  {'latitud': '390501N',
#   'provincia': 'CIUDAD REAL',
#   'altitud': '531',
#   'indicativo': '4220X',
#   'nombre': 'PUEBLA DE DON RODRIGO',
#   'indsinop': '08271',
#   'longitud': '043719W'},
#  {'latitud': '391009N',
#   'provincia': 'CIUDAD REAL',
#   'altitud': '662',
#   'indicativo': '4103X',
#   'nombre': 'TOMELLOSO',
#   'indsinop': '08276',
#   'longitud': '030027W'},
#  {'latitud': '384502N',
#   'provincia': 'CIUDAD REAL',
#   'altitud': '700',
#   'indicativo': '4147X',
#   'nombre': 'VALDEPEÑAS',
#   'indsinop': '08351',
#   'longitud': '032329W'},
#  {'latitud': '383105N',
#   'provincia': 'CIUDAD REAL',
#   'altitud': '804',
#   'indicativo': '4148',
#   'nombre': 'VISO DEL MARQUÉS',
#   'indsinop': '08345',
#   'longitud': '033400W'},
#  {'latitud': '382955N',
#   'provincia': 'CORDOBA',
#   'altitud': '551',
#   'indicativo': '4267X',
#   'nombre': 'HINOJOSA DEL DUQUE',
#   'indsinop': '08335',
#   'longitud': '050716W'},
#  {'latitud': '392500N',
#   'provincia': 'CUENCA',
#   'altitud': '728',
#   'indicativo': '4090Y',
#   'nombre': 'SAN CLEMENTE',
#   'indsinop': '08256',
#   'longitud': '022514W'},
#  {'latitud': '375207N',
#   'provincia': 'HUELVA',
#   'altitud': '572',
#   'indicativo': '4560Y',
#   'nombre': 'ALAJAR',
#   'indsinop': '08380',
#   'longitud': '064030W'},
#  {'latitud': '371141N',
#   'provincia': 'HUELVA',
#   'altitud': '3',
#   'indicativo': '4549Y',
#   'nombre': 'AYAMONTE',
#   'indsinop': '08381',
#   'longitud': '072342W'},
#  {'latitud': '371642N',
#   'provincia': 'HUELVA',
#   'altitud': '18',
#   'indicativo': '4642E',
#   'nombre': 'HUELVA, RONDA ESTE',
#   'indsinop': '08383',
#   'longitud': '065442W'},
#  {'latitud': '371524N',
#   'provincia': 'HUELVA',
#   'altitud': '17',
#   'indicativo': '4605',
#   'nombre': 'HUELVA',
#   'indsinop': '',
#   'longitud': '065659W'},
#  {'latitud': '392931N',
#   'provincia': 'TOLEDO',
#   'altitud': '690',
#   'indicativo': '4067',
#   'nombre': 'MADRIDEJOS',
#   'indsinop': '08273',
#   'longitud': '033142W'},
#  {'latitud': '393550N',
#   'provincia': 'TOLEDO',
#   'altitud': '692',
#   'indicativo': '4061X',
#   'nombre': 'QUINTANAR DE LA ORDEN',
#   'indsinop': '08275',
#   'longitud': '030254W'},
#  {'latitud': '362959N',
#   'provincia': 'CADIZ',
#   'altitud': '2',
#   'indicativo': '5973',
#   'nombre': 'CÁDIZ',
#   'indsinop': '08452',
#   'longitud': '061528W'},
#  {'latitud': '364538N',
#   'provincia': 'CADIZ',
#   'altitud': '913',
#   'indicativo': '5911A',
#   'nombre': 'GRAZALEMA',
#   'indsinop': '08455',
#   'longitud': '052227W'},
#  {'latitud': '364502N',
#   'provincia': 'CADIZ',
#   'altitud': '27',
#   'indicativo': '5960',
#   'nombre': 'JEREZ DE LA FRONTERA AEROPUERTO',
#   'indsinop': '08451',
#   'longitud': '060321W'},
#  {'latitud': '363820N',
#   'provincia': 'CADIZ',
#   'altitud': '21',
#   'indicativo': '5910',
#   'nombre': 'ROTA, BASE NAVAL',
#   'indsinop': '08449',
#   'longitud': '061957W'},
#  {'latitud': '362756N',
#   'provincia': 'CADIZ',
#   'altitud': '28',
#   'indicativo': '5972X',
#   'nombre': 'SAN FERNANDO',
#   'indsinop': '08453',
#   'longitud': '061220W'},
#  {'latitud': '361444N',
#   'provincia': 'CADIZ',
#   'altitud': '186',
#   'indicativo': '5995B',
#   'nombre': 'VEJER DE LA FRONTERA',
#   'indsinop': '08457',
#   'longitud': '055754W'},
#  {'latitud': '355344N',
#   'provincia': 'CEUTA',
#   'altitud': '200',
#   'indicativo': '5000A',
#   'nombre': 'CEUTA, MONTE HACHO',
#   'indsinop': '',
#   'longitud': '051732W'},
#  {'latitud': '355319N',
#   'provincia': 'CEUTA',
#   'altitud': '87',
#   'indicativo': '5000C',
#   'nombre': 'CEUTA',
#   'indsinop': '60320',
#   'longitud': '052049W'},
#  {'latitud': '375056N',
#   'provincia': 'CORDOBA',
#   'altitud': '90',
#   'indicativo': '5402',
#   'nombre': 'CÓRDOBA AEROPUERTO',
#   'indsinop': '08410',
#   'longitud': '045048W'},
#  {'latitud': '373322N',
#   'provincia': 'CORDOBA',
#   'altitud': '650',
#   'indicativo': '5427X',
#   'nombre': 'DOÑA MENCÍA',
#   'indsinop': '08412',
#   'longitud': '042114W'},
#  {'latitud': '381959N',
#   'provincia': 'CORDOBA',
#   'altitud': '750',
#   'indicativo': '5390Y',
#   'nombre': 'VILLANUEVA DE CÓRDOBA',
#   'indsinop': '08346',
#   'longitud': '043632W'},
#  {'latitud': '373021N',
#   'provincia': 'GRANADA',
#   'altitud': '785',
#   'indicativo': '5047E',
#   'nombre': 'BAZA',
#   'indsinop': '08424',
#   'longitud': '024406W'},
#  {'latitud': '371123N',
#   'provincia': 'GRANADA',
#   'altitud': '567',
#   'indicativo': '5530E',
#   'nombre': 'GRANADA AEROPUERTO',
#   'indsinop': '08419',
#   'longitud': '034722W'},
#  {'latitud': '370814N',
#   'provincia': 'GRANADA',
#   'altitud': '687',
#   'indicativo': '5514',
#   'nombre': 'GRANADA BASE AÉREA',
#   'indsinop': '08420',
#   'longitud': '033753W'},
#  {'latitud': '375140N',
#   'provincia': 'GRANADA',
#   'altitud': '1092',
#   'indicativo': '5051X',
#   'nombre': 'HUÉSCAR',
#   'indsinop': '08423',
#   'longitud': '023910W'},
#  {'latitud': '370940N',
#   'provincia': 'GRANADA',
#   'altitud': '760',
#   'indicativo': '5582A',
#   'nombre': 'LOJA',
#   'indsinop': '08414',
#   'longitud': '040910W'},
#  {'latitud': '370553N',
#   'provincia': 'HUELVA',
#   'altitud': '41',
#   'indicativo': '5860E',
#   'nombre': 'MOGUER, EL ARENOSILLO',
#   'indsinop': '08384',
#   'longitud': '064417W'},
#  {'latitud': '380123N',
#   'provincia': 'JAEN',
#   'altitud': '202',
#   'indicativo': '5298X',
#   'nombre': 'ANDÚJAR',
#   'indsinop': '08347',
#   'longitud': '040348W'},
#  {'latitud': '381853N',
#   'provincia': 'JAEN',
#   'altitud': '580',
#   'indicativo': '5181D',
#   'nombre': 'ARROYO DEL OJANCO',
#   'indsinop': '08352',
#   'longitud': '025323W'},
#  {'latitud': '375457N',
#   'provincia': 'JAEN',
#   'altitud': '782',
#   'indicativo': '5038X',
#   'nombre': 'CAZORLA',
#   'indsinop': '08353',
#   'longitud': '030014W'},
#  {'latitud': '374635N',
#   'provincia': 'JAEN',
#   'altitud': '510',
#   'indicativo': '5270',
#   'nombre': 'JAÉN, INSTITUTO',
#   'indsinop': '',
#   'longitud': '034720W'},
#  {'latitud': '374639N',
#   'provincia': 'JAEN',
#   'altitud': '580',
#   'indicativo': '5270B',
#   'nombre': 'JAÉN',
#   'indsinop': '08417',
#   'longitud': '034832W'},
#  {'latitud': '382040N',
#   'provincia': 'JAEN',
#   'altitud': '770',
#   'indicativo': '5246',
#   'nombre': 'SANTA ELENA',
#   'indsinop': '08350',
#   'longitud': '033207W'},
#  {'latitud': '382921N',
#   'provincia': 'JAEN',
#   'altitud': '862',
#   'indicativo': '5192',
#   'nombre': 'VILLARRODRIGO',
#   'indsinop': '08354',
#   'longitud': '023815W'},
#  {'latitud': '375535N',
#   'provincia': 'SEVILLA',
#   'altitud': '550',
#   'indicativo': '5704B',
#   'nombre': 'CAZALLA DE LA SIERRA',
#   'indsinop': '08392',
#   'longitud': '054611W'},
#  {'latitud': '373058N',
#   'provincia': 'SEVILLA',
#   'altitud': '130',
#   'indicativo': '5641X',
#   'nombre': 'ÉCIJA',
#   'indsinop': '08395',
#   'longitud': '050506W'},
#  {'latitud': '371140N',
#   'provincia': 'SEVILLA',
#   'altitud': '410',
#   'indicativo': '5612B',
#   'nombre': 'LA RODA DE ANDALUCÍA',
#   'indsinop': '08399',
#   'longitud': '044612W'},
#  {'latitud': '370952N',
#   'provincia': 'SEVILLA',
#   'altitud': '87',
#   'indicativo': '5796',
#   'nombre': 'MORÓN DE LA FRONTERA',
#   'indsinop': '08397',
#   'longitud': '053641W'},
#  {'latitud': '372500N',
#   'provincia': 'SEVILLA',
#   'altitud': '34',
#   'indicativo': '5783',
#   'nombre': 'SEVILLA AEROPUERTO',
#   'indsinop': '08391',
#   'longitud': '055245W'},
#  {'latitud': '370829N',
#   'provincia': 'ALMERIA',
#   'altitud': '869',
#   'indicativo': '6302A',
#   'nombre': 'ABLA',
#   'indsinop': '08427',
#   'longitud': '024648W'},
#  {'latitud': '364450N',
#   'provincia': 'ALMERIA',
#   'altitud': '8',
#   'indicativo': '6277B',
#   'nombre': 'ADRA',
#   'indsinop': '08486',
#   'longitud': '030114W'},
#  {'latitud': '355618N',
#   'provincia': 'ALMERIA',
#   'altitud': '15',
#   'indicativo': '6381',
#   'nombre': 'ALBORÁN',
#   'indsinop': '08490',
#   'longitud': '030210W'},
#  {'latitud': '365047N',
#   'provincia': 'ALMERIA',
#   'altitud': '21',
#   'indicativo': '6325O',
#   'nombre': 'ALMERÍA AEROPUERTO',
#   'indsinop': '08487',
#   'longitud': '022125W'},
#  {'latitud': '364952N',
#   'provincia': 'ALMERIA',
#   'altitud': '7',
#   'indicativo': '6297',
#   'nombre': 'ALMERÍA',
#   'indsinop': '',
#   'longitud': '022720W'},
#  {'latitud': '365849N',
#   'provincia': 'ALMERIA',
#   'altitud': '16',
#   'indicativo': '6332X',
#   'nombre': 'CARBONERAS',
#   'indsinop': '08488',
#   'longitud': '015413W'},
#  {'latitud': '372326N',
#   'provincia': 'ALMERIA',
#   'altitud': '300',
#   'indicativo': '6367B',
#   'nombre': 'HUÉRCAL-OVERA',
#   'indsinop': '08428',
#   'longitud': '015637W'},
#  {'latitud': '364113N',
#   'provincia': 'ALMERIA',
#   'altitud': '3',
#   'indicativo': '6293X',
#   'nombre': 'ROQUETAS DE MAR',
#   'indsinop': '08492',
#   'longitud': '024206W'},
#  {'latitud': '360050N',
#   'provincia': 'CADIZ',
#   'altitud': '32',
#   'indicativo': '6001',
#   'nombre': 'TARIFA',
#   'indsinop': '08458',
#   'longitud': '053556W'},
#  {'latitud': '364322N',
#   'provincia': 'GRANADA',
#   'altitud': '12',
#   'indicativo': '6268X',
#   'nombre': 'MOTRIL',
#   'indsinop': '08485',
#   'longitud': '033149W'},
#  {'latitud': '370146N',
#   'provincia': 'MALAGA',
#   'altitud': '408',
#   'indicativo': '6106X',
#   'nombre': 'ANTEQUERA',
#   'indsinop': '08413',
#   'longitud': '044454W'},
#  {'latitud': '362501N',
#   'provincia': 'MALAGA',
#   'altitud': '19',
#   'indicativo': '6058I',
#   'nombre': 'ESTEPONA',
#   'indsinop': '08463',
#   'longitud': '050918W'},
#  {'latitud': '363219N',
#   'provincia': 'MALAGA',
#   'altitud': '8',
#   'indicativo': '6084X',
#   'nombre': 'FUENGIROLA',
#   'indsinop': '08480',
#   'longitud': '043706W'},
#  {'latitud': '363958N',
#   'provincia': 'MALAGA',
#   'altitud': '5',
#   'indicativo': '6155A',
#   'nombre': 'MÁLAGA AEROPUERTO',
#   'indsinop': '08482',
#   'longitud': '042856W'},
#  {'latitud': '364304N',
#   'provincia': 'MALAGA',
#   'altitud': '54',
#   'indicativo': '6156X',
#   'nombre': 'MÁLAGA, CENTRO METEOROLÓGICO',
#   'indsinop': '08481',
#   'longitud': '042854W'},
#  {'latitud': '364300N',
#   'provincia': 'MALAGA',
#   'altitud': '25',
#   'indicativo': '6172O',
#   'nombre': 'MÁLAGA, PUERTO',
#   'indsinop': '08479',
#   'longitud': '042511W'},
#  {'latitud': '364459N',
#   'provincia': 'MALAGA',
#   'altitud': '766',
#   'indicativo': '6032B',
#   'nombre': 'RONDA',
#   'indsinop': '08443',
#   'longitud': '051006W'},
#  {'latitud': '364335N',
#   'provincia': 'MALAGA',
#   'altitud': '3',
#   'indicativo': '6205X',
#   'nombre': 'TORROX',
#   'indsinop': '08484',
#   'longitud': '035726W'},
#  {'latitud': '351635N',
#   'provincia': 'MELILLA',
#   'altitud': '52',
#   'indicativo': '6000A',
#   'nombre': 'MELILLA',
#   'indsinop': '60338',
#   'longitud': '025723W'},
#  {'latitud': '383231N',
#   'provincia': 'ALBACETE',
#   'altitud': '605',
#   'indicativo': '7096B',
#   'nombre': 'HELLÍN',
#   'indsinop': '08355',
#   'longitud': '014211W'},
#  {'latitud': '382359N',
#   'provincia': 'ALICANTE',
#   'altitud': '575',
#   'indicativo': '7247X',
#   'nombre': 'EL PINÓS/PINOSO',
#   'indsinop': '08357',
#   'longitud': '010217W'},
#  {'latitud': '372502N',
#   'provincia': 'MURCIA',
#   'altitud': '26',
#   'indicativo': '7002Y',
#   'nombre': 'ÁGUILAS',
#   'indsinop': '08432',
#   'longitud': '013513W'},
#  {'latitud': '375728N',
#   'provincia': 'MURCIA',
#   'altitud': '75',
#   'indicativo': '7228',
#   'nombre': 'ALCANTARILLA, BASE AÉREA',
#   'indsinop': '08429',
#   'longitud': '011343W'},
#  {'latitud': '380609N',
#   'provincia': 'MURCIA',
#   'altitud': '643',
#   'indicativo': '7119B',
#   'nombre': 'CARAVACA DE LA CRUZ',
#   'indsinop': '08365',
#   'longitud': '015238W'},
#  {'latitud': '373604N',
#   'provincia': 'MURCIA',
#   'altitud': '17',
#   'indicativo': '7012C',
#   'nombre': 'CARTAGENA',
#   'indsinop': '08434',
#   'longitud': '005916W'},
#  {'latitud': '381358N',
#   'provincia': 'MURCIA',
#   'altitud': '265',
#   'indicativo': '7145D',
#   'nombre': 'CIEZA',
#   'indsinop': '08363',
#   'longitud': '012250W'},
#  {'latitud': '373917N',
#   'provincia': 'MURCIA',
#   'altitud': '312',
#   'indicativo': '7209',
#   'nombre': 'LORCA',
#   'indsinop': '08426',
#   'longitud': '014114W'},
#  {'latitud': '380007N',
#   'provincia': 'MURCIA',
#   'altitud': '61',
#   'indicativo': '7178I',
#   'nombre': 'MURCIA',
#   'indsinop': '08430',
#   'longitud': '011015W'},
#  {'latitud': '374720N',
#   'provincia': 'MURCIA',
#   'altitud': '4',
#   'indicativo': '7031',
#   'nombre': 'SAN JAVIER AEROPUERTO',
#   'indsinop': '08433',
#   'longitud': '004812W'},
#  {'latitud': '374642N',
#   'provincia': 'MURCIA',
#   'altitud': '4',
#   'indicativo': '7031X',
#   'nombre': 'SAN JAVIER AEROPUERTO',
#   'indsinop': '08433',
#   'longitud': '004821W'},
#  {'latitud': '383606N',
#   'provincia': 'MURCIA',
#   'altitud': '640',
#   'indicativo': '7275C',
#   'nombre': 'YECLA',
#   'indsinop': '08356',
#   'longitud': '010935W'},
#  {'latitud': '385715N',
#   'provincia': 'ALBACETE',
#   'altitud': '702',
#   'indicativo': '8175',
#   'nombre': 'ALBACETE BASE AÉREA',
#   'indsinop': '08280',
#   'longitud': '015123W'},
#  {'latitud': '390021N',
#   'provincia': 'ALBACETE',
#   'altitud': '674',
#   'indicativo': '8178D',
#   'nombre': 'ALBACETE',
#   'indsinop': '08279',
#   'longitud': '015146W'},
#  {'latitud': '385609N',
#   'provincia': 'ALBACETE',
#   'altitud': '880',
#   'indicativo': '8177A',
#   'nombre': 'CHINCHILLA',
#   'indsinop': '08278',
#   'longitud': '013936W'},
#  {'latitud': '382221N',
#   'provincia': 'ALICANTE',
#   'altitud': '81',
#   'indicativo': '8025',
#   'nombre': 'ALACANT/ALICANTE',
#   'indsinop': '08359',
#   'longitud': '002939W'},
#  {'latitud': '381658N',
#   'provincia': 'ALICANTE',
#   'altitud': '43',
#   'indicativo': '8019',
#   'nombre': 'ALICANTE-ELCHE AEROPUERTO',
#   'indsinop': '08360',
#   'longitud': '003415W'},
#  {'latitud': '384701N',
#   'provincia': 'ALICANTE',
#   'altitud': '15',
#   'indicativo': '8050X',
#   'nombre': 'JÁVEA/ XÀBIA',
#   'indsinop': '08370',
#   'longitud': '001004E'},
#  {'latitud': '395726N',
#   'provincia': 'CASTELLON',
#   'altitud': '48',
#   'indicativo': '8500A',
#   'nombre': 'CASTELLÓ - ALMASSORA',
#   'indsinop': '08286',
#   'longitud': '000419W'},
#  {'latitud': '395921N',
#   'provincia': 'CASTELLON',
#   'altitud': '23',
#   'indicativo': '8501',
#   'nombre': 'CASTELLÓ DE LA PLANA',
#   'indsinop': '',
#   'longitud': '000156W'},
#  {'latitud': '402600N',
#   'provincia': 'CASTELLON',
#   'altitud': '1131',
#   'indicativo': '8489X',
#   'nombre': 'VILLAFRANCA DEL CID/VILLAFRANCA',
#   'indsinop': '08241',
#   'longitud': '001521W'},
#  {'latitud': '403315N',
#   'provincia': 'CASTELLON',
#   'altitud': '111',
#   'indicativo': '8523X',
#   'nombre': 'VINARÒS',
#   'indsinop': '08239',
#   'longitud': '002547E'},
#  {'latitud': '400402N',
#   'provincia': 'CUENCA',
#   'altitud': '948',
#   'indicativo': '8096',
#   'nombre': 'CUENCA',
#   'indsinop': '08231',
#   'longitud': '020755W'},
#  {'latitud': '402102N',
#   'provincia': 'TERUEL',
#   'altitud': '900',
#   'indicativo': '8368U',
#   'nombre': 'TERUEL',
#   'indsinop': '08235',
#   'longitud': '010727W'},
#  {'latitud': '385544N',
#   'provincia': 'VALENCIA',
#   'altitud': '5',
#   'indicativo': '8058X',
#   'nombre': 'OLIVA',
#   'indsinop': '08282',
#   'longitud': '000545W'},
#  {'latitud': '391105N',
#   'provincia': 'VALENCIA',
#   'altitud': '12',
#   'indicativo': '8325X',
#   'nombre': 'POLINYÀ DE XÚQUER',
#   'indsinop': '08287',
#   'longitud': '002219W'},
#  {'latitud': '393432N',
#   'provincia': 'VALENCIA',
#   'altitud': '758',
#   'indicativo': '8309X',
#   'nombre': 'UTIEL',
#   'indsinop': '08281',
#   'longitud': '011441W'},
#  {'latitud': '392906N',
#   'provincia': 'VALENCIA',
#   'altitud': '56',
#   'indicativo': '8414A',
#   'nombre': 'VALENCIA AEROPUERTO',
#   'indsinop': '08284',
#   'longitud': '002829W'},
#  {'latitud': '392850N',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'indicativo': '8416Y',
#   'nombre': 'VALÈNCIA, VIVEROS',
#   'indsinop': '08285',
#   'longitud': '002159W'},
#  {'latitud': '392850N',
#   'provincia': 'VALENCIA',
#   'altitud': '11',
#   'indicativo': '8416',
#   'nombre': 'VALÈNCIA',
#   'indsinop': '08285',
#   'longitud': '002159W'},
#  {'latitud': '390006N',
#   'provincia': 'VALENCIA',
#   'altitud': '88',
#   'indicativo': '8293X',
#   'nombre': 'XÀTIVA',
#   'indsinop': '08290',
#   'longitud': '003125W'},
#  {'latitud': '425255N',
#   'provincia': 'ARABA/ALAVA',
#   'altitud': '513',
#   'indicativo': '9091O',
#   'nombre': 'FORONDA-TXOKIZA',
#   'indsinop': '08080',
#   'longitud': '024406W'},
#  {'latitud': '425059N',
#   'provincia': 'ARABA/ALAVA',
#   'altitud': '521',
#   'indicativo': '9087',
#   'nombre': 'VITORIA AERÓDROMO',
#   'indsinop': '',
#   'longitud': '023922W'},
#  {'latitud': '425219N',
#   'provincia': 'ARABA/ALAVA',
#   'altitud': '513',
#   'indicativo': '9091R',
#   'nombre': 'VITORIA GASTEIZ AEROPUERTO',
#   'indsinop': '08080',
#   'longitud': '024358W'},
#  {'latitud': '422516N',
#   'provincia': 'BURGOS',
#   'altitud': '820',
#   'indicativo': '9111',
#   'nombre': 'BELORADO',
#   'indsinop': '08077',
#   'longitud': '031013W'},
#  {'latitud': '425512N',
#   'provincia': 'BURGOS',
#   'altitud': '580',
#   'indicativo': '9051',
#   'nombre': 'MEDINA DE POMAR',
#   'indsinop': '08063',
#   'longitud': '032858W'},
#  {'latitud': '425931N',
#   'provincia': 'CANTABRIA',
#   'altitud': '870',
#   'indicativo': '9001D',
#   'nombre': 'REINOSA',
#   'indsinop': '08032',
#   'longitud': '040938W'},
#  {'latitud': '424823N',
#   'provincia': 'CANTABRIA',
#   'altitud': '720',
#   'indicativo': '9019B',
#   'nombre': 'VALDERREDIBLE, POLIENTES   ',
#   'indsinop': '08033',
#   'longitud': '035602W'},
#  {'latitud': '402955N',
#   'provincia': 'CASTELLON',
#   'altitud': '1220',
#   'indicativo': '9563X',
#   'nombre': 'CASTELLFORT',
#   'indsinop': '08237',
#   'longitud': '001112W'},
#  {'latitud': '421957N',
#   'provincia': 'GIRONA',
#   'altitud': '1703',
#   'indicativo': '9585',
#   'nombre': 'LA MOLINA',
#   'indsinop': '08117',
#   'longitud': '015622E'},
#  {'latitud': '424232N',
#   'provincia': 'HUESCA',
#   'altitud': '1040',
#   'indicativo': '9208E',
#   'nombre': 'ARAGÜÉS DEL PUERTO',
#   'indsinop': '08095',
#   'longitud': '004023W'},
#  {'latitud': '423748N',
#   'provincia': 'HUESCA',
#   'altitud': '992',
#   'indicativo': '9784P',
#   'nombre': 'BIELSA',
#   'indsinop': '08103',
#   'longitud': '001329E'},
#  {'latitud': '420504N',
#   'provincia': 'HUESCA',
#   'altitud': '546',
#   'indicativo': '9898',
#   'nombre': 'HUESCA, AEROPUERTO',
#   'indsinop': '08094',
#   'longitud': '001932W'},
#  {'latitud': '423444N',
#   'provincia': 'HUESCA',
#   'altitud': '823',
#   'indicativo': '9201K',
#   'nombre': 'JACA',
#   'indsinop': '08091',
#   'longitud': '003249W'},
#  {'latitud': '423736N',
#   'provincia': 'HUESCA',
#   'altitud': '1020',
#   'indicativo': '9814A',
#   'nombre': 'TORLA',
#   'indsinop': '08101',
#   'longitud': '000642W'},
#  {'latitud': '422708N',
#   'provincia': 'LA RIOJA',
#   'altitud': '353',
#   'indicativo': '9170',
#   'nombre': 'LOGROÑO, AEROPUERTO',
#   'indsinop': '08084',
#   'longitud': '021952W'},
#  {'latitud': '422117N',
#   'provincia': 'LLEIDA',
#   'altitud': '677',
#   'indicativo': '9619',
#   'nombre': "LA SEU D'URGELL",
#   'indsinop': '08115',
#   'longitud': '012747E'},
#  {'latitud': '413702N',
#   'provincia': 'LLEIDA',
#   'altitud': '199',
#   'indicativo': '9771',
#   'nombre': 'LLEIDA, OBSERVATORIO',
#   'indsinop': '',
#   'longitud': '003716E'},
#  {'latitud': '413734N',
#   'provincia': 'LLEIDA',
#   'altitud': '185',
#   'indicativo': '9771C',
#   'nombre': 'LLEIDA',
#   'indsinop': '08171',
#   'longitud': '003553E'},
#  {'latitud': '424201N',
#   'provincia': 'LLEIDA',
#   'altitud': '1161',
#   'indicativo': '9990X',
#   'nombre': 'NAUT ARAN, ARTIES ',
#   'indsinop': '08107',
#   'longitud': '005237E'},
#  {'latitud': '421219N',
#   'provincia': 'LLEIDA',
#   'altitud': '807',
#   'indicativo': '9698U',
#   'nombre': 'TALARN',
#   'indsinop': '08112',
#   'longitud': '005155E'},
#  {'latitud': '413902N',
#   'provincia': 'LLEIDA',
#   'altitud': '388',
#   'indicativo': '9720X',
#   'nombre': 'TÀRREGA',
#   'indsinop': '08173',
#   'longitud': '010858E'},
#  {'latitud': '424634N',
#   'provincia': 'NAVARRA',
#   'altitud': '572',
#   'indicativo': '9263X',
#   'nombre': 'ARANGUREN, ILUNDAIN  ',
#   'indsinop': '08089',
#   'longitud': '013157W'},
#  {'latitud': '421155N',
#   'provincia': 'NAVARRA',
#   'altitud': '295',
#   'indicativo': '9294E',
#   'nombre': 'BARDENAS REALES, BASE AÉREA',
#   'indsinop': '08087',
#   'longitud': '012831W'},
#  {'latitud': '421225N',
#   'provincia': 'NAVARRA',
#   'altitud': '268',
#   'indicativo': '9283X',
#   'nombre': 'CADREITA',
#   'indsinop': '08153',
#   'longitud': '014241W'},
#  {'latitud': '424637N',
#   'provincia': 'NAVARRA',
#   'altitud': '459',
#   'indicativo': '9263D',
#   'nombre': 'PAMPLONA, AEROPUERTO',
#   'indsinop': '08085',
#   'longitud': '013900W'},
#  {'latitud': '424904N',
#   'provincia': 'NAVARRA',
#   'altitud': '450',
#   'indicativo': '9262',
#   'nombre': 'PAMPLONA',
#   'indsinop': '',
#   'longitud': '013818W'},
#  {'latitud': '404913N',
#   'provincia': 'TARRAGONA',
#   'altitud': '50',
#   'indicativo': '9981A',
#   'nombre': 'ESTACIÓN DE TORTOSA (ROQUETES)',
#   'indsinop': '08238',
#   'longitud': '002936E'},
#  {'latitud': '404157N',
#   'provincia': 'TARRAGONA',
#   'altitud': '1',
#   'indicativo': '9987P',
#   'nombre': "SANT JAUME D'ENVEJA",
#   'indsinop': '08240',
#   'longitud': '004836E'},
#  {'latitud': '410329N',
#   'provincia': 'TERUEL',
#   'altitud': '334',
#   'indicativo': '9573X',
#   'nombre': 'ALCAÑIZ',
#   'indsinop': '08164',
#   'longitud': '000830W'},
#  {'latitud': '405154N',
#   'provincia': 'TERUEL',
#   'altitud': '932',
#   'indicativo': '9381',
#   'nombre': 'CALAMOCHA, AERÓDROMO',
#   'indsinop': '',
#   'longitud': '011818W'},
#  {'latitud': '405534N',
#   'provincia': 'TERUEL',
#   'altitud': '890',
#   'indicativo': '9381I',
#   'nombre': 'CALAMOCHA',
#   'indsinop': '08233',
#   'longitud': '011736W'},
#  {'latitud': '405648N',
#   'provincia': 'TERUEL',
#   'altitud': '466',
#   'indicativo': '9569A',
#   'nombre': 'CALANDA',
#   'indsinop': '08166',
#   'longitud': '001416W'},
#  {'latitud': '413121N',
#   'provincia': 'ZARAGOZA',
#   'altitud': '357',
#   'indicativo': '9576C',
#   'nombre': 'BUJARALOZ',
#   'indsinop': '08165',
#   'longitud': '001028W'},
#  {'latitud': '411952N',
#   'provincia': 'ZARAGOZA',
#   'altitud': '582',
#   'indicativo': '9394X',
#   'nombre': 'CALATAYUD',
#   'indsinop': '08156',
#   'longitud': '013843W'},
#  {'latitud': '410652N',
#   'provincia': 'ZARAGOZA',
#   'altitud': '779',
#   'indicativo': '9390',
#   'nombre': 'DAROCA',
#   'indsinop': '08157',
#   'longitud': '012436W'},
#  {'latitud': '422927N',
#   'provincia': 'ZARAGOZA',
#   'altitud': '626',
#   'indicativo': '9244X',
#   'nombre': 'SOS DEL REY CATÓLICO',
#   'indsinop': '08090',
#   'longitud': '011249W'},
#  {'latitud': '413938N',
#   'provincia': 'ZARAGOZA',
#   'altitud': '249',
#   'indicativo': '9434',
#   'nombre': 'ZARAGOZA, AEROPUERTO',
#   'indsinop': '08160',
#   'longitud': '010015W'},
#  {'latitud': '413715N',
#   'provincia': 'ZARAGOZA',
#   'altitud': '254',
#   'indicativo': '9434P',
#   'nombre': 'ZARAGOZA, VALDESPARTERA',
#   'indsinop': '08159',
#   'longitud': '005606W'},
#  {'latitud': '394300N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '57',
#   'indicativo': 'B569X',
#   'nombre': 'CAPDEPERA',
#   'indsinop': '08311',
#   'longitud': '032841E'},
#  {'latitud': '394924N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '490',
#   'indicativo': 'B013X',
#   'nombre': 'ESCORCA, LLUC',
#   'indsinop': '08304',
#   'longitud': '025309E'},
#  {'latitud': '385235N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '6',
#   'indicativo': 'B954',
#   'nombre': 'IBIZA, AEROPUERTO',
#   'indsinop': '08373',
#   'longitud': '012304E'},
#  {'latitud': '395117N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '91',
#   'indicativo': 'B893',
#   'nombre': 'MENORCA, AEROPUERTO',
#   'indsinop': '08314',
#   'longitud': '041256E'},
#  {'latitud': '393339N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '8',
#   'indicativo': 'B278',
#   'nombre': 'PALMA DE MALLORCA, AEROPUERTO',
#   'indsinop': '08306',
#   'longitud': '024412E'},
#  {'latitud': '393319N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '3',
#   'indicativo': 'B228',
#   'nombre': 'PALMA, PUERTO',
#   'indsinop': '08301',
#   'longitud': '023731E'},
#  {'latitud': '393118N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '120',
#   'indicativo': 'B346X',
#   'nombre': 'PORRERES',
#   'indsinop': '08310',
#   'longitud': '030109E'},
#  {'latitud': '392452N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '17',
#   'indicativo': 'B434X',
#   'nombre': 'PORTOCOLOM  ',
#   'indsinop': '08309',
#   'longitud': '031618E'},
#  {'latitud': '394457N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '40',
#   'indicativo': 'B691Y',
#   'nombre': 'SA POBLA',
#   'indsinop': '08312',
#   'longitud': '030100E'},
#  {'latitud': '394406N',
#   'provincia': 'ILLES BALEARS',
#   'altitud': '1030',
#   'indicativo': 'B248',
#   'nombre': 'SIERRA DE ALFABIA, BUNYOLA',
#   'indsinop': '08303',
#   'longitud': '024247E'},
#  {'latitud': '282641N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '25',
#   'indicativo': 'C249I',
#   'nombre': 'FUERTEVENTURA AEROPUERTO',
#   'indsinop': '60035',
#   'longitud': '135147W'},
#  {'latitud': '275504N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '32',
#   'indicativo': 'C649I',
#   'nombre': 'GRAN CANARIA AEROPUERTO',
#   'indsinop': '60030',
#   'longitud': '152343W'},
#  {'latitud': '280003N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '10',
#   'indicativo': 'C619I',
#   'nombre': 'LA ALDEA DE SAN NICOLÁS',
#   'indsinop': '60027',
#   'longitud': '154850W'},
#  {'latitud': '285707N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '14',
#   'indicativo': 'C029O',
#   'nombre': 'LANZAROTE AEROPUERTO',
#   'indsinop': '60040',
#   'longitud': '133601W'},
#  {'latitud': '280647N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '15',
#   'indicativo': 'C659M',
#   'nombre': 'LAS PALMAS DE GRAN CANARIA, PL. DE LA FERIA',
#   'indsinop': '60032',
#   'longitud': '152517W'},
#  {'latitud': '280523N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '55',
#   'indicativo': 'C659H',
#   'nombre': 'LAS PALMAS DE GRAN CANARIA, SAN CRISTOBAL',
#   'indsinop': '60029',
#   'longitud': '152458W'},
#  {'latitud': '274409N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '6',
#   'indicativo': 'C689E',
#   'nombre': 'MASPALOMAS',
#   'indsinop': '60037',
#   'longitud': '153545W'},
#  {'latitud': '274859N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '10',
#   'indicativo': 'C629X',
#   'nombre': 'MOGÁN, PUERTO',
#   'indsinop': '60036',
#   'longitud': '154551W'},
#  {'latitud': '280257N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '15',
#   'indicativo': 'C229J',
#   'nombre': 'PÁJARA',
#   'indsinop': '60034',
#   'longitud': '142129W'},
#  {'latitud': '291355N',
#   'provincia': 'LAS PALMAS',
#   'altitud': '10',
#   'indicativo': 'C839I',
#   'nombre': 'TEGUISE',
#   'indsinop': '',
#   'longitud': '133007W'},
#  {'latitud': '281906N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '115',
#   'indicativo': 'C439J',
#   'nombre': 'GÜÍMAR',
#   'indsinop': '60018',
#   'longitud': '162256W'},
#  {'latitud': '274908N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '32',
#   'indicativo': 'C929I',
#   'nombre': 'HIERRO AEROPUERTO',
#   'indsinop': '60001',
#   'longitud': '175320W'},
#  {'latitud': '281832N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '2371',
#   'indicativo': 'C430E',
#   'nombre': 'IZAÑA',
#   'indsinop': '60010',
#   'longitud': '162958W'},
#  {'latitud': '283759N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '33',
#   'indicativo': 'C139E',
#   'nombre': 'LA PALMA AEROPUERTO',
#   'indsinop': '60005',
#   'longitud': '174518W'},
#  {'latitud': '282505N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '25',
#   'indicativo': 'C459Z',
#   'nombre': 'PUERTO DE LA CRUZ',
#   'indsinop': '60012',
#   'longitud': '163253W'},
#  {'latitud': '280523N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '15',
#   'indicativo': 'C329Z',
#   'nombre': 'SAN SEBASTIÁN DE LA GOMERA',
#   'indsinop': '60008',
#   'longitud': '170641W'},
#  {'latitud': '282748N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '35',
#   'indicativo': 'C449C',
#   'nombre': 'STA.CRUZ DE TENERIFE',
#   'indsinop': '60020',
#   'longitud': '161519W'},
#  {'latitud': '283545N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '62',
#   'indicativo': 'C129Z',
#   'nombre': 'TAZACORTE',
#   'indsinop': '60004',
#   'longitud': '175455W'},
#  {'latitud': '282839N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '632',
#   'indicativo': 'C447A',
#   'nombre': 'TENERIFE NORTE AEROPUERTO',
#   'indsinop': '60015',
#   'longitud': '161946W'},
#  {'latitud': '280249N',
#   'provincia': 'STA. CRUZ DE TENERIFE',
#   'altitud': '64',
#   'indicativo': 'C429I',
#   'nombre': 'TENERIFE SUR AEROPUERTO',
#   'indsinop': '60025',
#   'longitud': '163340W'}]

# %%
# Creamos el dataframe
estaciones_df = pd.DataFrame(response_data.json())
estaciones_df
# Out:
#      latitud              provincia altitud indicativo  \
# 0    413515N              BARCELONA      74      0252D
# 1    411734N              BARCELONA       4       0076
# 2    412506N              BARCELONA     408      0200E
# 3    412326N              BARCELONA       6      0201D
# 4    414312N              BARCELONA     291      0149X
# ..       ...                    ...     ...        ...
# 286  280523N  STA. CRUZ DE TENERIFE      15      C329Z
# 287  282748N  STA. CRUZ DE TENERIFE      35      C449C
# 288  283545N  STA. CRUZ DE TENERIFE      62      C129Z
# 289  282839N  STA. CRUZ DE TENERIFE     632      C447A
# 290  280249N  STA. CRUZ DE TENERIFE      64      C429I
#
#                          nombre indsinop longitud
# 0                 ARENYS DE MAR    08186  023224E
# 1          BARCELONA AEROPUERTO    08181  020412E
# 2              BARCELONA, FABRA           020727E
# 3                     BARCELONA    08180  021200E
# 4                       MANRESA    08174  015025E
# ..                          ...      ...      ...
# 286  SAN SEBASTIÁN DE LA GOMERA    60008  170641W
# 287        STA.CRUZ DE TENERIFE    60020  161519W
# 288                   TAZACORTE    60004  175455W
# 289   TENERIFE NORTE AEROPUERTO    60015  161946W
# 290     TENERIFE SUR AEROPUERTO    60025  163340W
#
# [291 rows x 7 columns]

# %%
estaciones_df.indicativo.unique()
# Out:
# array(['0252D', '0076', '0200E', '0201D', '0149X', '0229I', '0255B',
#        '0367', '0370B', '0372C', '0324A', '0016A', '0002I', '1387E',
#        '1387', '1393', '1351', '1400', '1437O', '1473A', '1428', '1475X',
#        '1212E', '1283U', '1210X', '1331A', '1207U', '1208A', '1208H',
#        '1208', '1183X', '1249I', '1249X', '1221D', '1542', '1082',
#        '1078I', '1055B', '1057B', '1059X', '1083L', '1159', '1109',
#        '1110', '1111', '1111X', '1024E', '1050J', '1014', '1014A',
#        '1041A', '1037Y', '1549', '1505', '1002Y', '1631E', '1700X',
#        '1690B', '1690A', '1735X', '1484', '1484C', '1495', '2444C',
#        '2444', '2811A', '2117D', '2331', '2298', '2737E', '2661B', '2661',
#        '2630X', '2462', '2400E', '2374X', '2235U', '2401', '2491C',
#        '2946X', '2867', '2870', '2916A', '2150H', '2465A', '2465', '2030',
#        '2503X', '2539', '2422', '2755X', '2775X', '2614', '3391', '3469',
#        '3469A', '3526X', '3434X', '3519X', '3463X', '3576X', '3044X',
#        '3094B', '3168C', '3168A', '3168D', '3013', '3130C', '3100B',
#        '3110C', '3191E', '3200', '3129', '3194U', '3196', '3195', '3266A',
#        '3338', '3111D', '3175', '3298X', '3365A', '3259', '3260B', '4452',
#        '4358X', '4244X', '4511C', '4386B', '4410X', '4121C', '4121',
#        '4220X', '4103X', '4147X', '4148', '4267X', '4090Y', '4560Y',
#        '4549Y', '4642E', '4605', '4067', '4061X', '5973', '5911A', '5960',
#        '5910', '5972X', '5995B', '5000A', '5000C', '5402', '5427X',
#        '5390Y', '5047E', '5530E', '5514', '5051X', '5582A', '5860E',
#        '5298X', '5181D', '5038X', '5270', '5270B', '5246', '5192',
#        '5704B', '5641X', '5612B', '5796', '5783', '6302A', '6277B',
#        '6381', '6325O', '6297', '6332X', '6367B', '6293X', '6001',
#        '6268X', '6106X', '6058I', '6084X', '6155A', '6156X', '6172O',
#        '6032B', '6205X', '6000A', '7096B', '7247X', '7002Y', '7228',
#        '7119B', '7012C', '7145D', '7209', '7178I', '7031', '7031X',
#        '7275C', '8175', '8178D', '8177A', '8025', '8019', '8050X',
#        '8500A', '8501', '8489X', '8523X', '8096', '8368U', '8058X',
#        '8325X', '8309X', '8414A', '8416Y', '8416', '8293X', '9091O',
#        '9087', '9091R', '9111', '9051', '9001D', '9019B', '9563X', '9585',
#        '9208E', '9784P', '9898', '9201K', '9814A', '9170', '9619', '9771',
#        '9771C', '9990X', '9698U', '9720X', '9263X', '9294E', '9283X',
#        '9263D', '9262', '9981A', '9987P', '9573X', '9381', '9381I',
#        '9569A', '9576C', '9394X', '9390', '9244X', '9434', '9434P',
#        'B569X', 'B013X', 'B954', 'B893', 'B278', 'B228', 'B346X', 'B434X',
#        'B691Y', 'B248', 'C249I', 'C649I', 'C619I', 'C029O', 'C659M',
#        'C659H', 'C689E', 'C629X', 'C229J', 'C839I', 'C439J', 'C929I',
#        'C430E', 'C139E', 'C459Z', 'C329Z', 'C449C', 'C129Z', 'C447A',
#        'C429I'], dtype=object)

# %%
estaciones_df.indicativo.value_counts().value_counts()
# Out:
# 1    291
# Name: indicativo, dtype: int64

# %%
estaciones_df.loc[estaciones_df.provincia == 'BARCELONA']
# Out:
#    latitud  provincia altitud indicativo                nombre indsinop  \
# 0  413515N  BARCELONA      74      0252D         ARENYS DE MAR    08186
# 1  411734N  BARCELONA       4       0076  BARCELONA AEROPUERTO    08181
# 2  412506N  BARCELONA     408      0200E      BARCELONA, FABRA
# 3  412326N  BARCELONA       6      0201D             BARCELONA    08180
# 4  414312N  BARCELONA     291      0149X               MANRESA    08174
# 5  413125N  BARCELONA     146      0229I   SABADELL AEROPUERTO    08192
# 6  413903N  BARCELONA      40      0255B         SANTA SUSANNA    08188
#
#   longitud
# 0  023224E
# 1  020412E
# 2  020727E
# 3  021200E
# 4  015025E
# 5  020611E
# 6  024149E

# %%
# Creo un listado de estaciones
lista_estaciones = ["BARCELONA AEROPUERTO", "ASTURIAS AEROPUERTO", 
                    "SEVILLA AEROPUERTO", "TENERIFE NORTE AEROPUERTO"]

indicativos = list(estaciones_df['indicativo'][estaciones_df.nombre.isin(lista_estaciones)])
indicativos
# Out:
# ['0076', '1212E', '5783', 'C447A']

# %%
# Valores climatológicos de las estaciones
fechaIni = '2022-09-01T00%3A00%3A00UTC'
fechaFin = '2022-09-08T00%3A00%3A00UTC'

df_4est = pd.DataFrame()

for id in indicativos:
    url = f"https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/{fechaIni}/fechafin/{fechaFin}/estacion/{id}"
    headers = {
    'cache-control' : 'no-cache'
    }

    querystring = {
        'api_key' : creds.creds_aemet.get('api_key')
    }

    # Creamos la solicitud

    response = requests.request('GET', url, headers=headers, params=querystring)
    print("La respuesta de la solicitud es {}. \n ".format(response.status_code))
    response_data = requests.get(response.json()['datos'], verify=False)
    
    # Creamos un dataframe temporal
    temp_df = pd.DataFrame(response_data.json())
    df_4est = pd.concat([df_4est, temp_df], ignore_index=True)

    print(df_4est.shape)

    # Introducimos un delay de 5 segundos
    print("Espera de 5 segundos \n")
    time.sleep(5)

df_4est.shape
df_4est
# Out:
# La respuesta de la solicitud es 200.
#
# (8, 20)
# Espera de 5 segundos
# c:\Users\mrusso\Miniconda3\envs\the_bridge_22\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'opendata.aemet.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# La respuesta de la solicitud es 200.
#
# (16, 20)
# Espera de 5 segundos
# c:\Users\mrusso\Miniconda3\envs\the_bridge_22\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'opendata.aemet.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# La respuesta de la solicitud es 200.
#
# (24, 20)
# Espera de 5 segundos
# c:\Users\mrusso\Miniconda3\envs\the_bridge_22\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'opendata.aemet.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# La respuesta de la solicitud es 200.
#
# (32, 20)
# Espera de 5 segundos
# c:\Users\mrusso\Miniconda3\envs\the_bridge_22\lib\site-packages\urllib3\connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'opendata.aemet.es'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
#          fecha indicativo                     nombre              provincia  \
# 0   2022-09-01       0076       BARCELONA AEROPUERTO              BARCELONA
# 1   2022-09-02       0076       BARCELONA AEROPUERTO              BARCELONA
# 2   2022-09-03       0076       BARCELONA AEROPUERTO              BARCELONA
# 3   2022-09-04       0076       BARCELONA AEROPUERTO              BARCELONA
# 4   2022-09-05       0076       BARCELONA AEROPUERTO              BARCELONA
# 5   2022-09-06       0076       BARCELONA AEROPUERTO              BARCELONA
# 6   2022-09-07       0076       BARCELONA AEROPUERTO              BARCELONA
# 7   2022-09-08       0076       BARCELONA AEROPUERTO              BARCELONA
# 8   2022-09-01      1212E        ASTURIAS AEROPUERTO               ASTURIAS
# 9   2022-09-02      1212E        ASTURIAS AEROPUERTO               ASTURIAS
# 10  2022-09-03      1212E        ASTURIAS AEROPUERTO               ASTURIAS
# 11  2022-09-04      1212E        ASTURIAS AEROPUERTO               ASTURIAS
# 12  2022-09-05      1212E        ASTURIAS AEROPUERTO               ASTURIAS
# 13  2022-09-06      1212E        ASTURIAS AEROPUERTO               ASTURIAS
# 14  2022-09-07      1212E        ASTURIAS AEROPUERTO               ASTURIAS
# 15  2022-09-08      1212E        ASTURIAS AEROPUERTO               ASTURIAS
# 16  2022-09-01       5783         SEVILLA AEROPUERTO                SEVILLA
# 17  2022-09-02       5783         SEVILLA AEROPUERTO                SEVILLA
# 18  2022-09-03       5783         SEVILLA AEROPUERTO                SEVILLA
# 19  2022-09-04       5783         SEVILLA AEROPUERTO                SEVILLA
# 20  2022-09-05       5783         SEVILLA AEROPUERTO                SEVILLA
# 21  2022-09-06       5783         SEVILLA AEROPUERTO                SEVILLA
# 22  2022-09-07       5783         SEVILLA AEROPUERTO                SEVILLA
# 23  2022-09-08       5783         SEVILLA AEROPUERTO                SEVILLA
# 24  2022-09-01      C447A  TENERIFE NORTE AEROPUERTO  STA. CRUZ DE TENERIFE
# 25  2022-09-02      C447A  TENERIFE NORTE AEROPUERTO  STA. CRUZ DE TENERIFE
# 26  2022-09-03      C447A  TENERIFE NORTE AEROPUERTO  STA. CRUZ DE TENERIFE
# 27  2022-09-04      C447A  TENERIFE NORTE AEROPUERTO  STA. CRUZ DE TENERIFE
# 28  2022-09-05      C447A  TENERIFE NORTE AEROPUERTO  STA. CRUZ DE TENERIFE
# 29  2022-09-06      C447A  TENERIFE NORTE AEROPUERTO  STA. CRUZ DE TENERIFE
# 30  2022-09-07      C447A  TENERIFE NORTE AEROPUERTO  STA. CRUZ DE TENERIFE
# 31  2022-09-08      C447A  TENERIFE NORTE AEROPUERTO  STA. CRUZ DE TENERIFE
#
#    altitud  tmed prec  tmin horatmin  tmax horatmax dir velmedia racha  \
# 0        4  24,8  0,0  19,4   Varias  30,2    13:37  36      4,2  10,3
# 1        4  27,0  0,0  23,1    23:14  30,9    15:11  10      5,3  11,7
# 2        4  26,0  0,0  22,7    05:16  29,3    12:20  08      5,6  12,5
# 3        4  26,3  0,0  23,1    05:15  29,5    12:40  99      4,2   8,3
# 4        4  27,1  0,0  23,8    05:58  30,4    10:41  12      4,4   9,7
# 5        4  27,0  0,0  23,1    23:31  30,8    13:52  23      5,6  10,6
# 6        4  26,2  0,0  21,8    05:48  30,5    11:16  99      3,1   8,3
# 7        4  26,4  0,0  23,6    03:21  29,3    12:31  99      4,4   8,3
# 8      127  18,6  0,1  15,0    05:07  22,2    14:26  99      3,1   7,2
# 9      127  18,0   Ip  15,1    03:57  20,9    09:17  27      3,9  11,4
# 10     127  18,0  0,0  13,8    05:52  22,3    14:43  20      2,8   6,7
# 11     127  18,6  0,0  13,2    03:12  24,1    10:57  18      3,6   8,9
# 12     127  21,6  0,0  16,1    22:18  27,2    11:40  99      3,1   8,3
# 13     127  22,2  0,0  16,7    02:06  27,7    12:56  27      3,9  13,9
# 14     127  20,8  0,4  15,7    06:15  26,0    13:51  24      2,2  12,8
# 15     127  19,4  0,0  16,6    03:18  22,3    13:08  99      3,1   6,7
# 16      34  24,8  0,0  16,7    06:07  33,0    14:53  23      3,3  12,8
# 17      34  26,7  0,0  19,5    06:39  33,9    15:24  22      4,2  11,4
# 18      34  24,6  0,0  17,4    06:12  31,8    16:03  99      4,7  12,5
# 19      34  23,2  0,0  15,2    05:02  31,3    15:56  99      4,2  10,8
# 20      34  24,0  0,0  15,6    05:59  32,4    15:30  21      4,2  10,3
# 21      34  25,2  0,0  16,9    05:37  33,5    16:17  99      1,9   9,2
# 22      34  26,6  0,0  19,6    02:11  33,7    15:16  30      3,1  10,8
# 23      34  26,2  0,0  17,4    05:05  35,0    15:55  22      3,1  10,3
# 24     632  22,5  0,1  19,2    05:59  25,8    11:47  99      3,3   8,9
# 25     632  23,2  0,0  19,0    23:57  27,5    12:20  29      5,0  13,3
# 26     632  20,6  0,0  17,7    05:39  23,4    13:33  29      4,2  13,3
# 27     632  21,0  0,0  16,9    03:58  25,0    13:36  29      5,0  10,8
# 28     632  21,2  0,0  17,2   Varias  25,2    13:07  99      5,3  10,3
# 29     632  20,5  0,0  16,9    03:46  24,1    11:47  99      6,9  13,9
# 30     632  20,4  0,0  17,0    03:44  23,8    13:15  99      7,5  13,9
# 31     632  21,0  0,0  17,7    00:11  24,2    14:05  30      8,1  15,0
#
#    horaracha   sol presMax horaPresMax presMin horaPresMin
# 0      01:48  11,5  1014,8          00  1011,8          18
# 1      17:57   8,7  1012,4          00  1008,5          17
# 2      01:30   5,6  1013,4      Varias  1010,5          03
# 3     Varias  10,3  1017,9      Varias  1013,4          00
# 4      10:24   6,2  1018,7      Varias  1015,7          18
# 5      16:15  11,4  1016,3          00  1012,9          17
# 6     Varias   7,6  1014,3      Varias  1010,7          18
# 7     Varias   4,2  1015,4      Varias  1011,4          00
# 8     Varias   7,1  1003,0          00  1000,7          06
# 9      10:14   2,1  1001,6      Varias  1000,2          05
# 10     05:23  12,4  1000,6          00   997,1          19
# 11     04:48   8,5  1000,8      Varias   998,2          13
# 12    Varias   7,6  1002,1      Varias   999,0          05
# 13     15:19   6,6  1002,1      Varias   999,9          14
# 14     10:35   3,2  1001,0          00   997,9          15
# 15    Varias   4,0  1004,0      Varias   999,6          03
# 16     17:25   4,7  1012,5      Varias  1009,6          16
# 17     17:41  10,8  1012,2      Varias  1008,2          18
# 18     17:04  12,3  1012,4      Varias  1008,7          16
# 19    Varias  12,4  1015,7      Varias  1012,0          02
# 20     17:21  12,4  1017,8      Varias  1014,3          17
# 21    Varias  12,2  1016,9      Varias  1011,9          17
# 22     14:58  11,1  1014,2      Varias  1010,3          18
# 23     18:34  12,3  1014,0      Varias  1010,4          17
# 24    Varias   0,2   949,4      Varias   946,3          07
# 25     22:20   2,7   949,6          24   947,6          01
# 26    Varias   4,4   950,0      Varias   947,8          06
# 27     20:07  10,3   951,6      Varias   948,1          04
# 28    Varias  11,4   953,0      Varias   950,3          03
# 29    Varias  10,9   952,6      Varias   950,0          15
# 30    Varias   9,1   950,8          00   948,6          15
# 31     20:10   9,1   950,9      Varias   948,0          04

# %% [markdown]
# # 4

# %%
import itertools

# Establecemos los parámetros
dia = ['1', '2']
area = ['p', 'b', 'c']

dict_incendios = {}
listas = [area, dia]

for a, d in itertools.product(*listas):
    print(f"Mustra la tupla {a}, {d}")

    url = f"https://opendata.aemet.es/opendata/api/incendios/mapasriesgo/previsto/dia/{d}/area/{a}"

    headers = {
    'cache-control' : 'no-cache'
    }

    querystring = {
        'api_key' : creds.creds_aemet.get('api_key')
    }

    # Creamos la solicitud

    response = requests.request('GET', url, headers=headers, params=querystring)
    print("La respuesta de la solicitud es {}. \n ".format(response.status_code))
    path_response_data = response.json()['datos']

    dict_incendios[a+d] = path_response_data

    # Introducimos un delay de 10 segundos
    print("Espera de 10 segundos \n")
    time.sleep(10)

dict_incendios
# Out:
# Mustra la tupla p, 1
# La respuesta de la solicitud es 200.
#
# Espera de 10 segundos
#
# Mustra la tupla p, 2
# La respuesta de la solicitud es 200.
#
# Espera de 10 segundos
#
# Mustra la tupla b, 1
# La respuesta de la solicitud es 200.
#
# Espera de 10 segundos
#
# Mustra la tupla b, 2
# La respuesta de la solicitud es 200.
#
# Espera de 10 segundos
#
# Mustra la tupla c, 1
# La respuesta de la solicitud es 200.
#
# Espera de 10 segundos
#
# Mustra la tupla c, 2
# La respuesta de la solicitud es 200.
#
# Espera de 10 segundos
# {'p1': 'https://opendata.aemet.es/opendata/sh/a014d624',
#  'p2': 'https://opendata.aemet.es/opendata/sh/66687e6e',
#  'b1': 'https://opendata.aemet.es/opendata/sh/fda2bd8a',
#  'b2': 'https://opendata.aemet.es/opendata/sh/26b7ed0c',
#  'c1': 'https://opendata.aemet.es/opendata/sh/a83fdab3',
#  'c2': 'https://opendata.aemet.es/opendata/sh/06e622ba'}

# %% [markdown]
# ## Crear el dataframe con las imagenes
#
# ```
# region |  Estados_actual | Prevision_2_dias

# %%
# Creamos el dataframe del json generado

df_incendios = pd.DataFrame(
    {"Estado_actual" : [dict_incendios.get(key) for key in dict_incendios if key.endswith('1')],
    "Prevision_2_dias" : [dict_incendios.get(key) for key in dict_incendios if key.endswith('2')]
    },
    index=[0,1,2]
)

# %%
df_incendios
# Out:
#                                     Estado_actual  \
# 0  https://opendata.aemet.es/opendata/sh/a014d624
# 1  https://opendata.aemet.es/opendata/sh/fda2bd8a
# 2  https://opendata.aemet.es/opendata/sh/a83fdab3
#
#                                  Prevision_2_dias
# 0  https://opendata.aemet.es/opendata/sh/66687e6e
# 1  https://opendata.aemet.es/opendata/sh/26b7ed0c
# 2  https://opendata.aemet.es/opendata/sh/06e622ba

# %%
## Código para visualizar mapas en el dataframe
from IPython.core.display import HTML

# convert your links to html tags 
def path_to_image_html(path):
    return '<img src="'+ path + '" width="400" >'

HTML(df_incendios.to_html(escape=False ,formatters={'Estado_actual': path_to_image_html,
                                                    'Prevision_2_dias': path_to_image_html}))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Estado_actual</th>
#       <th>Prevision_2_dias</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><img src="https://opendata.aemet.es/opendata/sh/a014d624" width="400" ></td>
#       <td><img src="https://opendata.aemet.es/opendata/sh/66687e6e" width="400" ></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td><img src="https://opendata.aemet.es/opendata/sh/fda2bd8a" width="400" ></td>
#       <td><img src="https://opendata.aemet.es/opendata/sh/26b7ed0c" width="400" ></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><img src="https://opendata.aemet.es/opendata/sh/a83fdab3" width="400" ></td>
#       <td><img src="https://opendata.aemet.es/opendata/sh/06e622ba" width="400" ></td>
#     </tr>
#   </tbody>
# </table>
