# %%
import datetime as dt
import pandas as pd
import requests

# %%
# los últimos 15 días
two_weeks = dt.date.today() - dt.timedelta(days=15)

ayer = dt.date.today() - dt.timedelta(days=1)

# %%
url = 'https://earthquake.usgs.gov/fdsnws/event/1/query'
starttime = two_weeks
endtime = ayer

# %%
payloads = {
    'format' : 'geojson',
    'starttime' : starttime,
    'endtime' : endtime
}

# %%
# Creo la solicitud
response = requests.get(url=url, params=payloads)
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'type': 'FeatureCollection',
#  'metadata': {'generated': 1667848363000,
#   'url': 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2022-10-23&endtime=2022-11-06',
#   'title': 'USGS Earthquakes',
#   'status': 200,
#   'api': '1.13.6',
#   'count': 3809},
#  'features': [{'type': 'Feature',
#    'properties': {'mag': 2.2,
#     'place': '46 km SW of Cantwell, Alaska',
#     'time': 1667692676302,
#     'updated': 1667692812367,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak022e7f3jny',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak022e7f3jny&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 74,
#     'net': 'ak',
#     'code': '022e7f3jny',
#     'ids': ',ak022e7f3jny,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.31,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.2 - 46 km SW of Cantwell, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-149.4841, 63.0503, 78.3]},
#    'id': 'ak022e7f3jny'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.86,
#     'place': '11km SW of The Geysers, CA',
#     'time': 1667692595930,
#     'updated': 1667772555340,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73804101',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73804101&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 11,
#     'net': 'nc',
#     'code': '73804101',
#     'ids': ',nc73804101,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 30,
#     'dmin': 0.05253,
#     'rms': 0.04,
#     'gap': 173,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 0.9 - 11km SW of The Geysers, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.8558333, 38.7166667, 4.86]},
#    'id': 'nc73804101'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.7,
#     'place': 'Bali region, Indonesia',
#     'time': 1667691998051,
#     'updated': 1667775336986,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000imyj',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000imyj&format=geojson',
#     'felt': 2,
#     'cdi': 3.4,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 211,
#     'net': 'us',
#     'code': '7000imyj',
#     'ids': ',us7000imyj,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 11,
#     'dmin': 1.153,
#     'rms': 0.87,
#     'gap': 157,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.7 - Bali region, Indonesia'},
#    'geometry': {'type': 'Point', 'coordinates': [115.243, -8.8794, 7.496]},
#    'id': 'us7000imyj'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.84,
#     'place': '6km NW of The Geysers, CA',
#     'time': 1667691880690,
#     'updated': 1667692510106,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73804086',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73804086&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 11,
#     'net': 'nc',
#     'code': '73804086',
#     'ids': ',nc73804086,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 10,
#     'dmin': 0.007938,
#     'rms': 0.02,
#     'gap': 56,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 0.8 - 6km NW of The Geysers, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.8000031, 38.8223343, 2.09]},
#    'id': 'nc73804086'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.7,
#     'place': '37 km W of Cantwell, Alaska',
#     'time': 1667691531222,
#     'updated': 1667691635832,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak022e7ezgo2',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak022e7ezgo2&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 44,
#     'net': 'ak',
#     'code': '022e7ezgo2',
#     'ids': ',ak022e7ezgo2,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 2.23,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.7 - 37 km W of Cantwell, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-149.7098, 63.3823, 74.7]},
#    'id': 'ak022e7ezgo2'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.44,
#     'place': '24km ESE of Anza, CA',
#     'time': 1667691522740,
#     'updated': 1667745916260,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40129415',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci40129415&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 32,
#     'net': 'ci',
#     'code': '40129415',
#     'ids': ',ci40129415,',
#     'sources': ',ci,',
#     'types': ',focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 52,
#     'dmin': 0.06367,
#     'rms': 0.22,
#     'gap': 33,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.4 - 24km ESE of Anza, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-116.4458333, 33.4618333, 8.48]},
#    'id': 'ci40129415'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.35,
#     'place': '11km SW of The Geysers, CA',
#     'time': 1667690240940,
#     'updated': 1667779093987,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73804081',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73804081&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 28,
#     'net': 'nc',
#     'code': '73804081',
#     'ids': ',nc73804081,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 44,
#     'dmin': 0.05204,
#     'rms': 0.06,
#     'gap': 59,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.4 - 11km SW of The Geysers, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.8521667, 38.7168333, 6.3]},
#    'id': 'nc73804081'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.7,
#     'place': '57 km NNW of Petersville, Alaska',
#     'time': 1667690208639,
#     'updated': 1667690387594,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak022e7euqpr',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak022e7euqpr&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 44,
#     'net': 'ak',
#     'code': '022e7euqpr',
#     'ids': ',ak022e7euqpr,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 1.08,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.7 - 57 km NNW of Petersville, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-151.2814, 62.9597, 23.1]},
#    'id': 'ak022e7euqpr'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.75,
#     'place': '11km SW of The Geysers, CA',
#     'time': 1667690083640,
#     'updated': 1667769974102,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73804076',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73804076&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 9,
#     'net': 'nc',
#     'code': '73804076',
#     'ids': ',nc73804076,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 33,
#     'dmin': 0.05448,
#     'rms': 0.05,
#     'gap': 76,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 0.8 - 11km SW of The Geysers, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-122.8583333, 38.715, 4.7]},
#    'id': 'nc73804076'},
#   {'type': 'Feature',
#    'properties': {'mag': -0.3,
#     'place': '36 km WNW of Indian Springs, Nevada',
#     'time': 1667689835829,
#     'updated': 1667702507302,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00850674',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nn00850674&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 0,
#     'net': 'nn',
#     'code': '00850674',
#     'ids': ',nn00850674,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 10,
#     'dmin': 0.042,
#     'rms': 0.0655,
#     'gap': 148.13,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M -0.3 - 36 km WNW of Indian Springs, Nevada'},
#    'geometry': {'type': 'Point', 'coordinates': [-116.0462, 36.6956, 2.9]},
#    'id': 'nn00850674'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.36,
#     'place': '11km SW of The Geysers, CA',
#     'time': 1667689755850,
#     'updated': 1667771113210,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73804066',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73804066&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 28,
#     'net': 'nc',
#     'code': '73804066',
#     'ids': ',nc73804066,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 43,
#     'dmin': 0.05526,
#     'rms': 0.05,
#     'gap': 82,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.4 - 11km SW of The Geysers, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-122.8566667, 38.714, 5.94]},
#    'id': 'nc73804066'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.2,
#     'place': '7km NW of The Geysers, CA',
#     'time': 1667689615030,
#     'updated': 1667694672335,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73804061',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73804061&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 22,
#     'net': 'nc',
#     'code': '73804061',
#     'ids': ',nc73804061,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 27,
#     'dmin': 0.003912,
#     'rms': 0.02,
#     'gap': 35,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.2 - 7km NW of The Geysers, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.805336, 38.8246651, 2.59]},
#    'id': 'nc73804061'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.74,
#     'place': '3km ESE of Berkeley, CA',
#     'time': 1667689498050,
#     'updated': 1667705476477,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73804056',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73804056&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 47,
#     'net': 'nc',
#     'code': '73804056',
#     'ids': ',nc73804056,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 29,
#     'dmin': 0.01256,
#     'rms': 0.06,
#     'gap': 63,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.7 - 3km ESE of Berkeley, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.2448349, 37.8660011, 9.27]},
#    'id': 'nc73804056'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.4,
#     'place': '17km ESE of Anza, CA',
#     'time': 1667689133940,
#     'updated': 1667771413898,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40129407',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci40129407&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 2,
#     'net': 'ci',
#     'code': '40129407',
#     'ids': ',ci40129407,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 20,
#     'dmin': 0.06103,
#     'rms': 0.11,
#     'gap': 69,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.4 - 17km ESE of Anza, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-116.506, 33.5, 12.83]},
#    'id': 'ci40129407'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.27,
#     'place': '17 km ENE of North Logan, Utah',
#     'time': 1667689022330,
#     'updated': 1667838539610,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/uu60523462',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uu60523462&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 79,
#     'net': 'uu',
#     'code': '60523462',
#     'ids': ',uu60523462,',
#     'sources': ',uu,',
#     'types': ',origin,phase-data,',
#     'nst': 27,
#     'dmin': 0.1223,
#     'rms': 0.15,
#     'gap': 49,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.3 - 17 km ENE of North Logan, Utah'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-111.6013333, 41.8015, 13.77]},
#    'id': 'uu60523462'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.11,
#     'place': '16 km E of North Logan, Utah',
#     'time': 1667688993780,
#     'updated': 1667839992200,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/uu60523457',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uu60523457&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 19,
#     'net': 'uu',
#     'code': '60523457',
#     'ids': ',uu60523457,',
#     'sources': ',uu,',
#     'types': ',origin,phase-data,',
#     'nst': 17,
#     'dmin': 0.12,
#     'rms': 0.14,
#     'gap': 119,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.1 - 16 km E of North Logan, Utah'},
#    'geometry': {'type': 'Point', 'coordinates': [-111.6046667, 41.7965, 14]},
#    'id': 'uu60523457'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.41,
#     'place': '10km SW of The Geysers, CA',
#     'time': 1667688405040,
#     'updated': 1667703135200,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73804046',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73804046&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 31,
#     'net': 'nc',
#     'code': '73804046',
#     'ids': ',nc73804046,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 17,
#     'dmin': 0.04389,
#     'rms': 0.04,
#     'gap': 218,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.4 - 10km SW of The Geysers, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.8483353, 38.7248344, 5.07]},
#    'id': 'nc73804046'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.37,
#     'place': '5km ESE of Yorba Linda, CA',
#     'time': 1667687923500,
#     'updated': 1667760049048,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40129399',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci40129399&format=geojson',
#     'felt': 1,
#     'cdi': 2.2,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 29,
#     'net': 'ci',
#     'code': '40129399',
#     'ids': ',ci40129399,',
#     'sources': ',ci,',
#     'types': ',dyfi,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 47,
#     'dmin': 0.05204,
#     'rms': 0.22,
#     'gap': 48,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.4 - 5km ESE of Yorba Linda, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-117.7638333, 33.8761667, 3.68]},
#    'id': 'ci40129399'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.9,
#     'place': '15 km WNW of Willow, Alaska',
#     'time': 1667687597219,
#     'updated': 1667687684246,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak022e7ecvux',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak022e7ecvux&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 56,
#     'net': 'ak',
#     'code': '022e7ecvux',
#     'ids': ',ak022e7ecvux,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.38,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.9 - 15 km WNW of Willow, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-150.3171, 61.7903, 38.1]},
#    'id': 'ak022e7ecvux'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.65,
#     'place': '4km NNE of Pinnacles, CA',
#     'time': 1667687203920,
#     'updated': 1667699712815,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73804041',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73804041&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 42,
#     'net': 'nc',
#     'code': '73804041',
#     'ids': ',nc73804041,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 11,
#     'dmin': 0.04783,
#     'rms': 0.14,
#     'gap': 119,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.7 - 4km NNE of Pinnacles, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.1268311, 36.5636673, 7.84]},
#    'id': 'nc73804041'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.1,
#     'place': '121 km N of The Valley, Anguilla',
#     'time': 1667687092691,
#     'updated': 1667706176040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000imsd',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000imsd&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 148,
#     'net': 'us',
#     'code': '7000imsd',
#     'ids': ',pr2022309000,us7000imsd,',
#     'sources': ',pr,us,',
#     'types': ',origin,phase-data,',
#     'nst': 16,
#     'dmin': 1.254,
#     'rms': 0.45,
#     'gap': 230,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 3.1 - 121 km N of The Valley, Anguilla'},
#    'geometry': {'type': 'Point', 'coordinates': [-63.2235, 19.3031, 39.179]},
#    'id': 'us7000imsd'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.97,
#     'place': '28 km E of Honaunau-Napoopoo, Hawaii',
#     'time': 1667686529880,
#     'updated': 1667686858610,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv73209512',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv73209512&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 60,
#     'net': 'hv',
#     'code': '73209512',
#     'ids': ',hv73209512,',
#     'sources': ',hv,',
#     'types': ',origin,phase-data,',
#     'nst': 16,
#     'dmin': None,
#     'rms': 0.239999995,
#     'gap': 56,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.0 - 28 km E of Honaunau-Napoopoo, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.591339111328, 19.4693336486816, -1.89999997615814]},
#    'id': 'hv73209512'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.18,
#     'place': '2km SE of Angwin, CA',
#     'time': 1667686421440,
#     'updated': 1667696593521,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73804031',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73804031&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 21,
#     'net': 'nc',
#     'code': '73804031',
#     'ids': ',nc73804031,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 9,
#     'dmin': 0.07488,
#     'rms': 0.02,
#     'gap': 134,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.2 - 2km SE of Angwin, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.4339981, 38.5595016, 4.65]},
#    'id': 'nc73804031'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.5,
#     'place': '6 km ESE of Fox, Alaska',
#     'time': 1667685970075,
#     'updated': 1667686105518,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak022e7e72z3',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak022e7e72z3&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 35,
#     'net': 'ak',
#     'code': '022e7e72z3',
#     'ids': ',ak022e7e72z3,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.72,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.5 - 6 km ESE of Fox, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-147.493, 64.9387, 3]},
#    'id': 'ak022e7e72z3'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.54,
#     'place': '1km NE of The Geysers, CA',
#     'time': 1667685824940,
#     'updated': 1667688012649,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73804016',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73804016&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 4,
#     'net': 'nc',
#     'code': '73804016',
#     'ids': ',nc73804016,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 5,
#     'dmin': 0.008858,
#     'rms': 0.01,
#     'gap': 104,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 0.5 - 1km NE of The Geysers, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.746666, 38.7874985, 1.86]},
#    'id': 'nc73804016'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.7,
#     'place': '29 km ESE of Cantwell, Alaska',
#     'time': 1667685724991,
#     'updated': 1667685874106,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak022e7e67pv',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak022e7e67pv&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 44,
#     'net': 'ak',
#     'code': '022e7e67pv',
#     'ids': ',ak022e7e67pv,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.74,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.7 - 29 km ESE of Cantwell, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-148.3996, 63.3042, 77.1]},
#    'id': 'ak022e7e67pv'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.5,
#     'place': '3 km WNW of Sierra City, California',
#     'time': 1667685647300,
#     'updated': 1667698101533,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00850672',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nn00850672&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 35,
#     'net': 'nn',
#     'code': '00850672',
#     'ids': ',nn00850672,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 8,
#     'dmin': 0.048,
#     'rms': 0.1884,
#     'gap': 216.18,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.5 - 3 km WNW of Sierra City, California'},
#    'geometry': {'type': 'Point', 'coordinates': [-120.6659, 39.5784, 9.7]},
#    'id': 'nn00850672'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.63,
#     'place': '4km SSW of Idyllwild, CA',
#     'time': 1667685582680,
#     'updated': 1667759452144,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40129383',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci40129383&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 6,
#     'net': 'ci',
#     'code': '40129383',
#     'ids': ',ci40129383,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 24,
#     'dmin': 0.0187,
#     'rms': 0.11,
#     'gap': 94,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.6 - 4km SSW of Idyllwild, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-116.7335, 33.7016667, 14.25]},
#    'id': 'ci40129383'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.22,
#     'place': '16km WNW of Westmorland, CA',
#     'time': 1667685491760,
#     'updated': 1667759110006,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40129375',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci40129375&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 23,
#     'net': 'ci',
#     'code': '40129375',
#     'ids': ',ci40129375,',
#     'sources': ',ci,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 31,
#     'dmin': 0.05423,
#     'rms': 0.22,
#     'gap': 75,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.2 - 16km WNW of Westmorland, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-115.7913333, 33.069, 6.97]},
#    'id': 'ci40129375'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.8,
#     'place': '53 km WNW of Ninilchik, Alaska',
#     'time': 1667685345841,
#     'updated': 1667685529761,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak022e7dw87o',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak022e7dw87o&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 50,
#     'net': 'ak',
#     'code': '022e7dw87o',
#     'ids': ',ak022e7dw87o,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.75,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.8 - 53 km WNW of Ninilchik, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-152.5889, 60.1896, 102.9]},
#    'id': 'ak022e7dw87o'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.5,
#     'place': '78 km SW of Banjar, Indonesia',
#     'time': 1667685072905,
#     'updated': 1667686979040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000ims2',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000ims2&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 312,
#     'net': 'us',
#     'code': '7000ims2',
#     'ids': ',us7000ims2,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 30,
#     'dmin': 0.752,
#     'rms': 1.3,
#     'gap': 173,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.5 - 78 km SW of Banjar, Indonesia'},
#    'geometry': {'type': 'Point', 'coordinates': [106.9276, -7.6939, 68.41]},
#    'id': 'us7000ims2'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.14,
#     'place': '6 km WSW of Volcano, Hawaii',
#     'time': 1667683793790,
#     'updated': 1667684125480,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv73209457',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv73209457&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 70,
#     'net': 'hv',
#     'code': '73209457',
#     'ids': ',hv73209457,',
#     'sources': ',hv,',
#     'types': ',origin,phase-data,',
#     'nst': 23,
#     'dmin': None,
#     'rms': 0.340000004,
#     'gap': 45,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.1 - 6 km WSW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.287002563477, 19.4104995727539, 1.00999999046326]},
#    'id': 'hv73209457'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.17,
#     'place': 'Island of Hawaii, Hawaii',
#     'time': 1667683200020,
#     'updated': 1667683529350,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv73209442',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv73209442&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 72,
#     'net': 'hv',
#     'code': '73209442',
#     'ids': ',hv73209442,',
#     'sources': ',hv,',
#     'types': ',origin,phase-data,',
#     'nst': 42,
#     'dmin': None,
#     'rms': 0.140000001,
#     'gap': 44,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.2 - Island of Hawaii, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.473327636719, 19.4158325195312, 8.11999988555908]},
#    'id': 'hv73209442'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.3,
#     'place': '4 km WSW of Ferry, Alaska',
#     'time': 1667682366533,
#     'updated': 1667682507777,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak022e7dln3h',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak022e7dln3h&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 26,
#     'net': 'ak',
#     'code': '022e7dln3h',
#     'ids': ',ak022e7dln3h,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.35,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.3 - 4 km WSW of Ferry, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-149.2112, 64.0002, 9.7]},
#    'id': 'ak022e7dln3h'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.22,
#     'place': '14km ESE of Alum Rock, CA',
#     'time': 1667682130930,
#     'updated': 1667694914362,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73804011',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73804011&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 23,
#     'net': 'nc',
#     'code': '73804011',
#     'ids': ',nc73804011,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 11,
#     'dmin': 0.04397,
#     'rms': 0.02,
#     'gap': 97,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.2 - 14km ESE of Alum Rock, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.6848297, 37.3133316, 6.8]},
#    'id': 'nc73804011'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.05999994,
#     'place': '8 km SSW of P?hala, Hawaii',
#     'time': 1667681772830,
#     'updated': 1667681958970,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv73209402',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv73209402&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 65,
#     'net': 'hv',
#     'code': '73209402',
#     'ids': ',hv73209402,',
#     'sources': ',hv,',
#     'types': ',origin,phase-data,',
#     'nst': 38,
#     'dmin': None,
#     'rms': 0.109999999,
#     'gap': 223,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.1 - 8 km SSW of P?hala, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.517669677734, 19.1354999542236, 37.0299987792969]},
#    'id': 'hv73209402'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.8,
#     'place': '19 km N of Fishhook, Alaska',
#     'time': 1667681499698,
#     'updated': 1667681609397,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak022e7d9x9t',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak022e7d9x9t&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 50,
#     'net': 'ak',
#     'code': '022e7d9x9t',
#     'ids': ',ak022e7d9x9t,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.62,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.8 - 19 km N of Fishhook, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-149.2197, 61.9155, 7.5]},
#    'id': 'ak022e7d9x9t'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.3,
#     'place': '52 km W of Anchor Point, Alaska',
#     'time': 1667681330936,
#     'updated': 1667683170040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak022e7d9b0a',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak022e7d9b0a&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 81,
#     'net': 'ak',
#     'code': '022e7d9b0a',
#     'ids': ',us7000imrx,ak022e7d9b0a,',
#     'sources': ',us,ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.37,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.3 - 52 km W of Anchor Point, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-152.7506, 59.8588, 95.2]},
#    'id': 'ak022e7d9b0a'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.69,
#     'place': '0km E of Carson, CA',
#     'time': 1667680773120,
#     'updated': 1667784875173,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40129359',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci40129359&format=geojson',
#     'felt': 167,
#     'cdi': 3.7,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 173,
#     'net': 'ci',
#     'code': '40129359',
#     'ids': ',ci40129359,us7000imrw,',
#     'sources': ',ci,us,',
#     'types': ',dyfi,focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 75,
#     'dmin': 0.0384,
#     'rms': 0.27,
#     'gap': 63,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.7 - 0km E of Carson, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-118.2781667, 33.8315, 11.22]},
#    'id': 'ci40129359'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.4,
#     'place': 'Nevada',
#     'time': 1667680373267,
#     'updated': 1667680577762,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00850668',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nn00850668&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 30,
#     'net': 'nn',
#     'code': '00850668',
#     'ids': ',nn00850668,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 13,
#     'dmin': 0.076,
#     'rms': 0.1258,
#     'gap': 168.38,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.4 - Nevada'},
#    'geometry': {'type': 'Point', 'coordinates': [-117.8775, 38.1797, 6.4]},
#    'id': 'nn00850668'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.4,
#     'place': '35 km SE of Mina, Nevada',
#     'time': 1667678970830,
#     'updated': 1667679166022,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00850667',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nn00850667&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 2,
#     'net': 'nn',
#     'code': '00850667',
#     'ids': ',nn00850667,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 8,
#     'dmin': 0.092,
#     'rms': 0.1837,
#     'gap': 171.69,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.4 - 35 km SE of Mina, Nevada'},
#    'geometry': {'type': 'Point', 'coordinates': [-117.8435, 38.1483, 13.4]},
#    'id': 'nn00850667'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.9,
#     'place': 'Southern Alaska',
#     'time': 1667678875127,
#     'updated': 1667678995346,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak022e7d0iyg',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak022e7d0iyg&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 56,
#     'net': 'ak',
#     'code': '022e7d0iyg',
#     'ids': ',ak022e7d0iyg,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.35,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.9 - Southern Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-151.1941, 61.8907, 88.9]},
#    'id': 'ak022e7d0iyg'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.32,
#     'place': '7 km SW of Corinne, Utah',
#     'time': 1667678278780,
#     'updated': 1667842494420,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/uu60523412',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uu60523412&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 27,
#     'net': 'uu',
#     'code': '60523412',
#     'ids': ',uu60523412,',
#     'sources': ',uu,',
#     'types': ',origin,phase-data,',
#     'nst': 18,
#     'dmin': 0.1036,
#     'rms': 0.12,
#     'gap': 64,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.3 - 7 km SW of Corinne, Utah'},
#    'geometry': {'type': 'Point', 'coordinates': [-112.176, 41.503, 5.7]},
#    'id': 'uu60523412'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.9,
#     'place': '73 km SSW of Sofifi, Indonesia',
#     'time': 1667677289025,
#     'updated': 1667678061040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000imrl',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000imrl&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 369,
#     'net': 'us',
#     'code': '7000imrl',
#     'ids': ',us7000imrl,',
#     'sources': ',us,',
#     'types': ',origin,phase-data,',
#     'nst': 38,
#     'dmin': 0.655,
#     'rms': 0.77,
#     'gap': 106,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.9 - 73 km SSW of Sofifi, Indonesia'},
#    'geometry': {'type': 'Point', 'coordinates': [127.3296, 0.1134, 147.333]},
#    'id': 'us7000imrl'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.85,
#     'place': '7km NW of The Geysers, CA',
#     'time': 1667677047100,
#     'updated': 1667677870559,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73804006',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73804006&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 11,
#     'net': 'nc',
#     'code': '73804006',
#     'ids': ',nc73804006,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 8,
#     'dmin': 0.003782,
#     'rms': 0.02,
#     'gap': 79,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 0.9 - 7km NW of The Geysers, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.8105011, 38.8271675, 1.36]},
#    'id': 'nc73804006'},
#   {'type': 'Feature',
#    'properties': {'mag': -0.4,
#     'place': '36 km WNW of Indian Springs, Nevada',
#     'time': 1667676450757,
#     'updated': 1667702504248,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00850673',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nn00850673&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 0,
#     'net': 'nn',
#     'code': '00850673',
#     'ids': ',nn00850673,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 7,
#     'dmin': 0.041,
#     'rms': 0.0366,
#     'gap': 147.74,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M -0.4 - 36 km WNW of Indian Springs, Nevada'},
#    'geometry': {'type': 'Point', 'coordinates': [-116.0478, 36.6961, 3.7]},
#    'id': 'nn00850673'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.75,
#     'place': '6km NW of The Geysers, CA',
#     'time': 1667676323070,
#     'updated': 1667677271499,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73804001',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73804001&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 9,
#     'net': 'nc',
#     'code': '73804001',
#     'ids': ',nc73804001,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 9,
#     'dmin': 0.008535,
#     'rms': 0.01,
#     'gap': 142,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 0.8 - 6km NW of The Geysers, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.7993317, 38.8218346, 2.39]},
#    'id': 'nc73804001'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.5,
#     'place': '5 km SE of Cold Springs, Nevada',
#     'time': 1667675885215,
#     'updated': 1667697726457,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00850671',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nn00850671&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 4,
#     'net': 'nn',
#     'code': '00850671',
#     'ids': ',nn00850671,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 6,
#     'dmin': 0.037,
#     'rms': 0.1211,
#     'gap': 79.45,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.5 - 5 km SE of Cold Springs, Nevada'},
#    'geometry': {'type': 'Point', 'coordinates': [-119.9392, 39.6406, 4.8]},
#    'id': 'nn00850671'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.08,
#     'place': '2km SSW of Parkfield, CA',
#     'time': 1667675400280,
#     'updated': 1667675497644,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73803996',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73803996&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 18,
#     'net': 'nc',
#     'code': '73803996',
#     'ids': ',nc73803996,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,',
#     'nst': 13,
#     'dmin': 0.01551,
#     'rms': 0.08,
#     'gap': 202,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.1 - 2km SSW of Parkfield, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.4358368, 35.8839989, 5.46]},
#    'id': 'nc73803996'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.58,
#     'place': '38 km NNE of Amboy, Washington',
#     'time': 1667675393930,
#     'updated': 1667756466660,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/uw61893006',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uw61893006&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 5,
#     'net': 'uw',
#     'code': '61893006',
#     'ids': ',uw61893006,',
#     'sources': ',uw,',
#     'types': ',origin,phase-data,',
#     'nst': 14,
#     'dmin': 0.007212,
#     'rms': 0.17,
#     'gap': 75,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 0.6 - 38 km NNE of Amboy, Washington'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.17583333333333, 46.20283333333333, 5.16]},
#    'id': 'uw61893006'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.5,
#     'place': '15 km S of Susitna North, Alaska',
#     'time': 1667675299003,
#     'updated': 1667675462076,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak022e7cf89o',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak022e7cf89o&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 35,
#     'net': 'ak',
#     'code': '022e7cf89o',
#     'ids': ',ak022e7cf89o,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.36,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.5 - 15 km S of Susitna North, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-149.8798, 62.0237, 34.7]},
#    'id': 'ak022e7cf89o'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.8,
#     'place': '14km NW of Pinnacles, CA',
#     'time': 1667675208590,
#     'updated': 1667704035304,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73803991',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73803991&format=geojson',
#     'felt': 4,
#     'cdi': 2.7,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 122,
#     'net': 'nc',
#     'code': '73803991',
#     'ids': ',nc73803991,us7000imrj,',
#     'sources': ',nc,us,',
#     'types': ',dyfi,focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 79,
#     'dmin': 0.05395,
#     'rms': 0.11,
#     'gap': 54,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.8 - 14km NW of Pinnacles, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-121.2515, 36.629, 9.46]},
#    'id': 'nc73803991'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.4,
#     'place': '55 km S of Whites City, New Mexico',
#     'time': 1667675029253,
#     'updated': 1667838823068,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2022vser',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=tx2022vser&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 89,
#     'net': 'tx',
#     'code': '2022vser',
#     'ids': ',tx2022vser,',
#     'sources': ',tx,',
#     'types': ',origin,phase-data,',
#     'nst': 12,
#     'dmin': 0.01452572935,
#     'rms': 0.3,
#     'gap': 82,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.4 - 55 km S of Whites City, New Mexico'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-104.4091944, 31.6774401, 6.542895508]},
#    'id': 'tx2022vser'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.35,
#     'place': '7km NW of The Geysers, CA',
#     'time': 1667674970410,
#     'updated': 1667676370411,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73803981',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73803981&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
# ...
#     'time': 1667356545040,
#     'updated': 1667366293770,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73802271',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73802271&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 1,
#     'net': 'nc',
#     'code': '73802271',
#     'ids': ',nc73802271,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 11,
#     'dmin': 0.06565,
#     'rms': 0.04,
#     'gap': 303,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 0.2 - 16km WSW of Toms Place, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-118.8553333, 37.5276667, 8.53]},
#    'id': 'nc73802271'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.1,
#     'place': '44 km NW of Toyah, Texas',
#     'time': 1667355541603,
#     'updated': 1667414352272,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2022vlla',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=tx2022vlla&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 68,
#     'net': 'tx',
#     'code': '2022vlla',
#     'ids': ',tx2022vlla,',
#     'sources': ',tx,',
#     'types': ',origin,phase-data,',
#     'nst': 26,
#     'dmin': 0.03992395631,
#     'rms': 0.1,
#     'gap': 60,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.1 - 44 km NW of Toyah, Texas'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-104.1041053, 31.61106665, 7.674047852000001]},
#    'id': 'tx2022vlla'},
#   {'type': 'Feature',
#    'properties': {'mag': 3.3,
#     'place': '73 km N of Charlotte Amalie, U.S. Virgin Islands',
#     'time': 1667355367310,
#     'updated': 1667422379150,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71380493',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=pr71380493&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 168,
#     'net': 'pr',
#     'code': '71380493',
#     'ids': ',pr71380493,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 14,
#     'dmin': 0.6517,
#     'rms': 0.22,
#     'gap': 271,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 3.3 - 73 km N of Charlotte Amalie, U.S. Virgin Islands'},
#    'geometry': {'type': 'Point', 'coordinates': [-64.997, 19.0065, 21.15]},
#    'id': 'pr71380493'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.28,
#     'place': '1 km ENE of Magna, Utah',
#     'time': 1667354862350,
#     'updated': 1667403788640,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/uu60522622',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uu60522622&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 1,
#     'net': 'uu',
#     'code': '60522622',
#     'ids': ',uu60522622,',
#     'sources': ',uu,',
#     'types': ',origin,phase-data,',
#     'nst': 5,
#     'dmin': 0.06667,
#     'rms': 0.02,
#     'gap': 113,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 0.3 - 1 km ENE of Magna, Utah'},
#    'geometry': {'type': 'Point', 'coordinates': [-112.0815, 40.7123333, 9.25]},
#    'id': 'uu60522622'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.4,
#     'place': None,
#     'time': 1667354669591,
#     'updated': 1667408508740,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00850443',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nn00850443&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 30,
#     'net': 'nn',
#     'code': '00850443',
#     'ids': ',nn00850443,',
#     'sources': ',nn,',
#     'types': ',origin,phase-data,',
#     'nst': 15,
#     'dmin': 0.06,
#     'rms': 0.1504,
#     'gap': 160.09,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.4 - '},
#    'geometry': {'type': 'Point', 'coordinates': [-117.8943, 38.1693, 7.9]},
#    'id': 'nn00850443'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.93,
#     'place': '6 km E of La Parguera, Puerto Rico',
#     'time': 1667354232200,
#     'updated': 1667355027110,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71380488',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=pr71380488&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 57,
#     'net': 'pr',
#     'code': '71380488',
#     'ids': ',pr71380488,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 6,
#     'dmin': 0.0532,
#     'rms': 0.06,
#     'gap': 185,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.9 - 6 km E of La Parguera, Puerto Rico'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-66.9883333333333, 17.9688333333333, 11.48]},
#    'id': 'pr71380488'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.52,
#     'place': '1km NNW of Larkfield-Wikiup, CA',
#     'time': 1667354209930,
#     'updated': 1667378953045,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73802266',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73802266&format=geojson',
#     'felt': 2,
#     'cdi': 3.4,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 36,
#     'net': 'nc',
#     'code': '73802266',
#     'ids': ',nc73802266,',
#     'sources': ',nc,',
#     'types': ',dyfi,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 42,
#     'dmin': 0.1237,
#     'rms': 0.14,
#     'gap': 46,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.5 - 1km NNW of Larkfield-Wikiup, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-122.7535, 38.5183333, 5.56]},
#    'id': 'nc73802266'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.99,
#     'place': '8 km W of Pawnee, Oklahoma',
#     'time': 1667353391140,
#     'updated': 1667392202423,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ok2022vljv',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ok2022vljv&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 15,
#     'net': 'ok',
#     'code': '2022vljv',
#     'ids': ',ok2022vljv,',
#     'sources': ',ok,',
#     'types': ',origin,phase-data,',
#     'nst': 46,
#     'dmin': 0.06208781625,
#     'rms': 0.22,
#     'gap': 78,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.0 - 8 km W of Pawnee, Oklahoma'},
#    'geometry': {'type': 'Point', 'coordinates': [-96.89433333, 36.33, 6.23]},
#    'id': 'ok2022vljv'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.29,
#     'place': '11km WNW of Toms Place, CA',
#     'time': 1667353351550,
#     'updated': 1667363651497,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73802261',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73802261&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 1,
#     'net': 'nc',
#     'code': '73802261',
#     'ids': ',nc73802261,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 10,
#     'dmin': 0.01955,
#     'rms': 0.02,
#     'gap': 276,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 0.3 - 11km WNW of Toms Place, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-118.8045, 37.5896667, 4.18]},
#    'id': 'nc73802261'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.97000003,
#     'place': '11 km E of P?hala, Hawaii',
#     'time': 1667352811470,
#     'updated': 1667353004740,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv73204162',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv73204162&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 60,
#     'net': 'hv',
#     'code': '73204162',
#     'ids': ',hv73204162,',
#     'sources': ',hv,',
#     'types': ',origin,phase-data,',
#     'nst': 34,
#     'dmin': None,
#     'rms': 0.159999996,
#     'gap': 164,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.0 - 11 km E of P?hala, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.364501953125, 19.2031669616699, 30.1800003051758]},
#    'id': 'hv73204162'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.62,
#     'place': '9km W of Toms Place, CA',
#     'time': 1667352805170,
#     'updated': 1667365934733,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73802246',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73802246&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 40,
#     'net': 'nc',
#     'code': '73802246',
#     'ids': ',nc73802246,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 15,
#     'dmin': 0.03806,
#     'rms': 0.02,
#     'gap': 217,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.6 - 9km W of Toms Place, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-118.7858353, 37.5736656, 6.3]},
#    'id': 'nc73802246'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.9,
#     'place': '60 km WNW of Tatitlek, Alaska',
#     'time': 1667352578602,
#     'updated': 1667352710212,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak022e237xgk',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak022e237xgk&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 56,
#     'net': 'ak',
#     'code': '022e237xgk',
#     'ids': ',ak022e237xgk,',
#     'sources': ',ak,',
#     'types': ',origin,phase-data,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.89,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.9 - 60 km WNW of Tatitlek, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-147.7242, 61.0563, 113.7]},
#    'id': 'ak022e237xgk'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.3,
#     'place': '23 km SSW of Mammoth, Wyoming',
#     'time': 1667352327400,
#     'updated': 1667401749260,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/uu60522582',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uu60522582&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 26,
#     'net': 'uu',
#     'code': '60522582',
#     'ids': ',uu60522582,',
#     'sources': ',uu,',
#     'types': ',origin,phase-data,',
#     'nst': 14,
#     'dmin': 0.0232,
#     'rms': 0.15,
#     'gap': 107,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.3 - 23 km SSW of Mammoth, Wyoming'},
#    'geometry': {'type': 'Point', 'coordinates': [-110.8181667, 44.7855, 3.91]},
#    'id': 'uu60522582'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.96,
#     'place': '1km WNW of Kensington, CA',
#     'time': 1667352105710,
#     'updated': 1667364252702,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73802241',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73802241&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 14,
#     'net': 'nc',
#     'code': '73802241',
#     'ids': ',nc73802241,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 23,
#     'dmin': 0.01828,
#     'rms': 0.08,
#     'gap': 48,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.0 - 1km WNW of Kensington, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-122.294, 37.916, 4.44]},
#    'id': 'nc73802241'},
#   {'type': 'Feature',
#    'properties': {'mag': -0.07,
#     'place': '24 km SSW of Mammoth, Wyoming',
#     'time': 1667351301800,
#     'updated': 1667403201880,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/uu60522572',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uu60522572&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 0,
#     'net': 'uu',
#     'code': '60522572',
#     'ids': ',uu60522572,',
#     'sources': ',uu,',
#     'types': ',origin,phase-data,',
#     'nst': 7,
#     'dmin': 0.03348,
#     'rms': 0.04,
#     'gap': 182,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M -0.1 - 24 km SSW of Mammoth, Wyoming'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-110.8093333, 44.7721667, 3.27]},
#    'id': 'uu60522572'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.01,
#     'place': '3 km E of Maria Antonia, Puerto Rico',
#     'time': 1667351174970,
#     'updated': 1667352589610,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71380483',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=pr71380483&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 62,
#     'net': 'pr',
#     'code': '71380483',
#     'ids': ',pr71380483,',
#     'sources': ',pr,',
#     'types': ',origin,phase-data,',
#     'nst': 10,
#     'dmin': 0.02235,
#     'rms': 0.12,
#     'gap': 197,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.0 - 3 km E of Maria Antonia, Puerto Rico'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-66.8558333333333, 17.9766666666667, 18.41]},
#    'id': 'pr71380483'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.5,
#     'place': 'Guam region',
#     'time': 1667349750220,
#     'updated': 1667375136006,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000iluv',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000iluv&format=geojson',
#     'felt': 7,
#     'cdi': 3.6,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 314,
#     'net': 'us',
#     'code': '7000iluv',
#     'ids': ',us7000iluv,',
#     'sources': ',us,',
#     'types': ',dyfi,origin,phase-data,',
#     'nst': 19,
#     'dmin': 0.383,
#     'rms': 0.72,
#     'gap': 93,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.5 - Guam region'},
#    'geometry': {'type': 'Point', 'coordinates': [144.6595, 13.9158, 185.839]},
#    'id': 'us7000iluv'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.15,
#     'place': '6km NW of The Geysers, CA',
#     'time': 1667349670950,
#     'updated': 1667362872551,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73802231',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73802231&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 20,
#     'net': 'nc',
#     'code': '73802231',
#     'ids': ',nc73802231,',
#     'sources': ',nc,',
#     'types': ',nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 22,
#     'dmin': 0.006152,
#     'rms': 0.02,
#     'gap': 41,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.2 - 6km NW of The Geysers, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.80867, 38.8173332, 2.99]},
#    'id': 'nc73802231'},
#   ...],
#  'bbox': [-179.9973, -60.7962, -3.5, 179.701, 82.8052, 628.102]}

# %%
terremotos = response.json()
terremotos.keys()
# Out:
# dict_keys(['type', 'metadata', 'features', 'bbox'])

# %%
terremotos['features']
# Out:
# [{'type': 'Feature',
#   'properties': {'mag': 2.2,
#    'place': '46 km SW of Cantwell, Alaska',
#    'time': 1667692676302,
#    'updated': 1667692812367,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak022e7f3jny',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak022e7f3jny&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 74,
#    'net': 'ak',
#    'code': '022e7f3jny',
#    'ids': ',ak022e7f3jny,',
#    'sources': ',ak,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.31,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.2 - 46 km SW of Cantwell, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-149.4841, 63.0503, 78.3]},
#   'id': 'ak022e7f3jny'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.86,
#    'place': '11km SW of The Geysers, CA',
#    'time': 1667692595930,
#    'updated': 1667772555340,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73804101',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73804101&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 11,
#    'net': 'nc',
#    'code': '73804101',
#    'ids': ',nc73804101,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 30,
#    'dmin': 0.05253,
#    'rms': 0.04,
#    'gap': 173,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 0.9 - 11km SW of The Geysers, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.8558333, 38.7166667, 4.86]},
#   'id': 'nc73804101'},
#  {'type': 'Feature',
#   'properties': {'mag': 3.7,
#    'place': 'Bali region, Indonesia',
#    'time': 1667691998051,
#    'updated': 1667775336986,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000imyj',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000imyj&format=geojson',
#    'felt': 2,
#    'cdi': 3.4,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 211,
#    'net': 'us',
#    'code': '7000imyj',
#    'ids': ',us7000imyj,',
#    'sources': ',us,',
#    'types': ',dyfi,origin,phase-data,',
#    'nst': 11,
#    'dmin': 1.153,
#    'rms': 0.87,
#    'gap': 157,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 3.7 - Bali region, Indonesia'},
#   'geometry': {'type': 'Point', 'coordinates': [115.243, -8.8794, 7.496]},
#   'id': 'us7000imyj'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.84,
#    'place': '6km NW of The Geysers, CA',
#    'time': 1667691880690,
#    'updated': 1667692510106,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73804086',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73804086&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 11,
#    'net': 'nc',
#    'code': '73804086',
#    'ids': ',nc73804086,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 10,
#    'dmin': 0.007938,
#    'rms': 0.02,
#    'gap': 56,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 0.8 - 6km NW of The Geysers, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.8000031, 38.8223343, 2.09]},
#   'id': 'nc73804086'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.7,
#    'place': '37 km W of Cantwell, Alaska',
#    'time': 1667691531222,
#    'updated': 1667691635832,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak022e7ezgo2',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak022e7ezgo2&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 44,
#    'net': 'ak',
#    'code': '022e7ezgo2',
#    'ids': ',ak022e7ezgo2,',
#    'sources': ',ak,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 2.23,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.7 - 37 km W of Cantwell, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-149.7098, 63.3823, 74.7]},
#   'id': 'ak022e7ezgo2'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.44,
#    'place': '24km ESE of Anza, CA',
#    'time': 1667691522740,
#    'updated': 1667745916260,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40129415',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci40129415&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 32,
#    'net': 'ci',
#    'code': '40129415',
#    'ids': ',ci40129415,',
#    'sources': ',ci,',
#    'types': ',focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 52,
#    'dmin': 0.06367,
#    'rms': 0.22,
#    'gap': 33,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.4 - 24km ESE of Anza, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-116.4458333, 33.4618333, 8.48]},
#   'id': 'ci40129415'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.35,
#    'place': '11km SW of The Geysers, CA',
#    'time': 1667690240940,
#    'updated': 1667779093987,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73804081',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73804081&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 28,
#    'net': 'nc',
#    'code': '73804081',
#    'ids': ',nc73804081,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 44,
#    'dmin': 0.05204,
#    'rms': 0.06,
#    'gap': 59,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.4 - 11km SW of The Geysers, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.8521667, 38.7168333, 6.3]},
#   'id': 'nc73804081'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.7,
#    'place': '57 km NNW of Petersville, Alaska',
#    'time': 1667690208639,
#    'updated': 1667690387594,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak022e7euqpr',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak022e7euqpr&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 44,
#    'net': 'ak',
#    'code': '022e7euqpr',
#    'ids': ',ak022e7euqpr,',
#    'sources': ',ak,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 1.08,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.7 - 57 km NNW of Petersville, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-151.2814, 62.9597, 23.1]},
#   'id': 'ak022e7euqpr'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.75,
#    'place': '11km SW of The Geysers, CA',
#    'time': 1667690083640,
#    'updated': 1667769974102,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73804076',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73804076&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 9,
#    'net': 'nc',
#    'code': '73804076',
#    'ids': ',nc73804076,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 33,
#    'dmin': 0.05448,
#    'rms': 0.05,
#    'gap': 76,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 0.8 - 11km SW of The Geysers, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-122.8583333, 38.715, 4.7]},
#   'id': 'nc73804076'},
#  {'type': 'Feature',
#   'properties': {'mag': -0.3,
#    'place': '36 km WNW of Indian Springs, Nevada',
#    'time': 1667689835829,
#    'updated': 1667702507302,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00850674',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nn00850674&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 0,
#    'net': 'nn',
#    'code': '00850674',
#    'ids': ',nn00850674,',
#    'sources': ',nn,',
#    'types': ',origin,phase-data,',
#    'nst': 10,
#    'dmin': 0.042,
#    'rms': 0.0655,
#    'gap': 148.13,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M -0.3 - 36 km WNW of Indian Springs, Nevada'},
#   'geometry': {'type': 'Point', 'coordinates': [-116.0462, 36.6956, 2.9]},
#   'id': 'nn00850674'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.36,
#    'place': '11km SW of The Geysers, CA',
#    'time': 1667689755850,
#    'updated': 1667771113210,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73804066',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73804066&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 28,
#    'net': 'nc',
#    'code': '73804066',
#    'ids': ',nc73804066,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 43,
#    'dmin': 0.05526,
#    'rms': 0.05,
#    'gap': 82,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.4 - 11km SW of The Geysers, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-122.8566667, 38.714, 5.94]},
#   'id': 'nc73804066'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.2,
#    'place': '7km NW of The Geysers, CA',
#    'time': 1667689615030,
#    'updated': 1667694672335,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73804061',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73804061&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 22,
#    'net': 'nc',
#    'code': '73804061',
#    'ids': ',nc73804061,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 27,
#    'dmin': 0.003912,
#    'rms': 0.02,
#    'gap': 35,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.2 - 7km NW of The Geysers, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.805336, 38.8246651, 2.59]},
#   'id': 'nc73804061'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.74,
#    'place': '3km ESE of Berkeley, CA',
#    'time': 1667689498050,
#    'updated': 1667705476477,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73804056',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73804056&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 47,
#    'net': 'nc',
#    'code': '73804056',
#    'ids': ',nc73804056,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 29,
#    'dmin': 0.01256,
#    'rms': 0.06,
#    'gap': 63,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.7 - 3km ESE of Berkeley, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.2448349, 37.8660011, 9.27]},
#   'id': 'nc73804056'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.4,
#    'place': '17km ESE of Anza, CA',
#    'time': 1667689133940,
#    'updated': 1667771413898,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40129407',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci40129407&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 2,
#    'net': 'ci',
#    'code': '40129407',
#    'ids': ',ci40129407,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 20,
#    'dmin': 0.06103,
#    'rms': 0.11,
#    'gap': 69,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 0.4 - 17km ESE of Anza, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-116.506, 33.5, 12.83]},
#   'id': 'ci40129407'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.27,
#    'place': '17 km ENE of North Logan, Utah',
#    'time': 1667689022330,
#    'updated': 1667838539610,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/uu60523462',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uu60523462&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 79,
#    'net': 'uu',
#    'code': '60523462',
#    'ids': ',uu60523462,',
#    'sources': ',uu,',
#    'types': ',origin,phase-data,',
#    'nst': 27,
#    'dmin': 0.1223,
#    'rms': 0.15,
#    'gap': 49,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.3 - 17 km ENE of North Logan, Utah'},
#   'geometry': {'type': 'Point', 'coordinates': [-111.6013333, 41.8015, 13.77]},
#   'id': 'uu60523462'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.11,
#    'place': '16 km E of North Logan, Utah',
#    'time': 1667688993780,
#    'updated': 1667839992200,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/uu60523457',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uu60523457&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 19,
#    'net': 'uu',
#    'code': '60523457',
#    'ids': ',uu60523457,',
#    'sources': ',uu,',
#    'types': ',origin,phase-data,',
#    'nst': 17,
#    'dmin': 0.12,
#    'rms': 0.14,
#    'gap': 119,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.1 - 16 km E of North Logan, Utah'},
#   'geometry': {'type': 'Point', 'coordinates': [-111.6046667, 41.7965, 14]},
#   'id': 'uu60523457'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.41,
#    'place': '10km SW of The Geysers, CA',
#    'time': 1667688405040,
#    'updated': 1667703135200,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73804046',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73804046&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 31,
#    'net': 'nc',
#    'code': '73804046',
#    'ids': ',nc73804046,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 17,
#    'dmin': 0.04389,
#    'rms': 0.04,
#    'gap': 218,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.4 - 10km SW of The Geysers, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.8483353, 38.7248344, 5.07]},
#   'id': 'nc73804046'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.37,
#    'place': '5km ESE of Yorba Linda, CA',
#    'time': 1667687923500,
#    'updated': 1667760049048,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40129399',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci40129399&format=geojson',
#    'felt': 1,
#    'cdi': 2.2,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 29,
#    'net': 'ci',
#    'code': '40129399',
#    'ids': ',ci40129399,',
#    'sources': ',ci,',
#    'types': ',dyfi,nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 47,
#    'dmin': 0.05204,
#    'rms': 0.22,
#    'gap': 48,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.4 - 5km ESE of Yorba Linda, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-117.7638333, 33.8761667, 3.68]},
#   'id': 'ci40129399'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.9,
#    'place': '15 km WNW of Willow, Alaska',
#    'time': 1667687597219,
#    'updated': 1667687684246,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak022e7ecvux',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak022e7ecvux&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 56,
#    'net': 'ak',
#    'code': '022e7ecvux',
#    'ids': ',ak022e7ecvux,',
#    'sources': ',ak,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.38,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.9 - 15 km WNW of Willow, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-150.3171, 61.7903, 38.1]},
#   'id': 'ak022e7ecvux'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.65,
#    'place': '4km NNE of Pinnacles, CA',
#    'time': 1667687203920,
#    'updated': 1667699712815,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73804041',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73804041&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 42,
#    'net': 'nc',
#    'code': '73804041',
#    'ids': ',nc73804041,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 11,
#    'dmin': 0.04783,
#    'rms': 0.14,
#    'gap': 119,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.7 - 4km NNE of Pinnacles, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-121.1268311, 36.5636673, 7.84]},
#   'id': 'nc73804041'},
#  {'type': 'Feature',
#   'properties': {'mag': 3.1,
#    'place': '121 km N of The Valley, Anguilla',
#    'time': 1667687092691,
#    'updated': 1667706176040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000imsd',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000imsd&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 148,
#    'net': 'us',
#    'code': '7000imsd',
#    'ids': ',pr2022309000,us7000imsd,',
#    'sources': ',pr,us,',
#    'types': ',origin,phase-data,',
#    'nst': 16,
#    'dmin': 1.254,
#    'rms': 0.45,
#    'gap': 230,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 3.1 - 121 km N of The Valley, Anguilla'},
#   'geometry': {'type': 'Point', 'coordinates': [-63.2235, 19.3031, 39.179]},
#   'id': 'us7000imsd'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.97,
#    'place': '28 km E of Honaunau-Napoopoo, Hawaii',
#    'time': 1667686529880,
#    'updated': 1667686858610,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv73209512',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv73209512&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 60,
#    'net': 'hv',
#    'code': '73209512',
#    'ids': ',hv73209512,',
#    'sources': ',hv,',
#    'types': ',origin,phase-data,',
#    'nst': 16,
#    'dmin': None,
#    'rms': 0.239999995,
#    'gap': 56,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.0 - 28 km E of Honaunau-Napoopoo, Hawaii'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-155.591339111328, 19.4693336486816, -1.89999997615814]},
#   'id': 'hv73209512'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.18,
#    'place': '2km SE of Angwin, CA',
#    'time': 1667686421440,
#    'updated': 1667696593521,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73804031',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73804031&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 21,
#    'net': 'nc',
#    'code': '73804031',
#    'ids': ',nc73804031,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 9,
#    'dmin': 0.07488,
#    'rms': 0.02,
#    'gap': 134,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.2 - 2km SE of Angwin, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.4339981, 38.5595016, 4.65]},
#   'id': 'nc73804031'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.5,
#    'place': '6 km ESE of Fox, Alaska',
#    'time': 1667685970075,
#    'updated': 1667686105518,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak022e7e72z3',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak022e7e72z3&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 35,
#    'net': 'ak',
#    'code': '022e7e72z3',
#    'ids': ',ak022e7e72z3,',
#    'sources': ',ak,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.72,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.5 - 6 km ESE of Fox, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-147.493, 64.9387, 3]},
#   'id': 'ak022e7e72z3'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.54,
#    'place': '1km NE of The Geysers, CA',
#    'time': 1667685824940,
#    'updated': 1667688012649,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73804016',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73804016&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 4,
#    'net': 'nc',
#    'code': '73804016',
#    'ids': ',nc73804016,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 5,
#    'dmin': 0.008858,
#    'rms': 0.01,
#    'gap': 104,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 0.5 - 1km NE of The Geysers, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.746666, 38.7874985, 1.86]},
#   'id': 'nc73804016'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.7,
#    'place': '29 km ESE of Cantwell, Alaska',
#    'time': 1667685724991,
#    'updated': 1667685874106,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak022e7e67pv',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak022e7e67pv&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 44,
#    'net': 'ak',
#    'code': '022e7e67pv',
#    'ids': ',ak022e7e67pv,',
#    'sources': ',ak,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.74,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.7 - 29 km ESE of Cantwell, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-148.3996, 63.3042, 77.1]},
#   'id': 'ak022e7e67pv'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.5,
#    'place': '3 km WNW of Sierra City, California',
#    'time': 1667685647300,
#    'updated': 1667698101533,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00850672',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nn00850672&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 35,
#    'net': 'nn',
#    'code': '00850672',
#    'ids': ',nn00850672,',
#    'sources': ',nn,',
#    'types': ',origin,phase-data,',
#    'nst': 8,
#    'dmin': 0.048,
#    'rms': 0.1884,
#    'gap': 216.18,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.5 - 3 km WNW of Sierra City, California'},
#   'geometry': {'type': 'Point', 'coordinates': [-120.6659, 39.5784, 9.7]},
#   'id': 'nn00850672'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.63,
#    'place': '4km SSW of Idyllwild, CA',
#    'time': 1667685582680,
#    'updated': 1667759452144,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40129383',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci40129383&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 6,
#    'net': 'ci',
#    'code': '40129383',
#    'ids': ',ci40129383,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 24,
#    'dmin': 0.0187,
#    'rms': 0.11,
#    'gap': 94,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 0.6 - 4km SSW of Idyllwild, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-116.7335, 33.7016667, 14.25]},
#   'id': 'ci40129383'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.22,
#    'place': '16km WNW of Westmorland, CA',
#    'time': 1667685491760,
#    'updated': 1667759110006,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40129375',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci40129375&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 23,
#    'net': 'ci',
#    'code': '40129375',
#    'ids': ',ci40129375,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 31,
#    'dmin': 0.05423,
#    'rms': 0.22,
#    'gap': 75,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.2 - 16km WNW of Westmorland, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-115.7913333, 33.069, 6.97]},
#   'id': 'ci40129375'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.8,
#    'place': '53 km WNW of Ninilchik, Alaska',
#    'time': 1667685345841,
#    'updated': 1667685529761,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak022e7dw87o',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak022e7dw87o&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 50,
#    'net': 'ak',
#    'code': '022e7dw87o',
#    'ids': ',ak022e7dw87o,',
#    'sources': ',ak,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.75,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.8 - 53 km WNW of Ninilchik, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-152.5889, 60.1896, 102.9]},
#   'id': 'ak022e7dw87o'},
#  {'type': 'Feature',
#   'properties': {'mag': 4.5,
#    'place': '78 km SW of Banjar, Indonesia',
#    'time': 1667685072905,
#    'updated': 1667686979040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000ims2',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000ims2&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 312,
#    'net': 'us',
#    'code': '7000ims2',
#    'ids': ',us7000ims2,',
#    'sources': ',us,',
#    'types': ',origin,phase-data,',
#    'nst': 30,
#    'dmin': 0.752,
#    'rms': 1.3,
#    'gap': 173,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 4.5 - 78 km SW of Banjar, Indonesia'},
#   'geometry': {'type': 'Point', 'coordinates': [106.9276, -7.6939, 68.41]},
#   'id': 'us7000ims2'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.14,
#    'place': '6 km WSW of Volcano, Hawaii',
#    'time': 1667683793790,
#    'updated': 1667684125480,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv73209457',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv73209457&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 70,
#    'net': 'hv',
#    'code': '73209457',
#    'ids': ',hv73209457,',
#    'sources': ',hv,',
#    'types': ',origin,phase-data,',
#    'nst': 23,
#    'dmin': None,
#    'rms': 0.340000004,
#    'gap': 45,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.1 - 6 km WSW of Volcano, Hawaii'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-155.287002563477, 19.4104995727539, 1.00999999046326]},
#   'id': 'hv73209457'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.17,
#    'place': 'Island of Hawaii, Hawaii',
#    'time': 1667683200020,
#    'updated': 1667683529350,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv73209442',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv73209442&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 72,
#    'net': 'hv',
#    'code': '73209442',
#    'ids': ',hv73209442,',
#    'sources': ',hv,',
#    'types': ',origin,phase-data,',
#    'nst': 42,
#    'dmin': None,
#    'rms': 0.140000001,
#    'gap': 44,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.2 - Island of Hawaii, Hawaii'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-155.473327636719, 19.4158325195312, 8.11999988555908]},
#   'id': 'hv73209442'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.3,
#    'place': '4 km WSW of Ferry, Alaska',
#    'time': 1667682366533,
#    'updated': 1667682507777,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak022e7dln3h',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak022e7dln3h&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 26,
#    'net': 'ak',
#    'code': '022e7dln3h',
#    'ids': ',ak022e7dln3h,',
#    'sources': ',ak,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.35,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.3 - 4 km WSW of Ferry, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-149.2112, 64.0002, 9.7]},
#   'id': 'ak022e7dln3h'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.22,
#    'place': '14km ESE of Alum Rock, CA',
#    'time': 1667682130930,
#    'updated': 1667694914362,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73804011',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73804011&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 23,
#    'net': 'nc',
#    'code': '73804011',
#    'ids': ',nc73804011,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 11,
#    'dmin': 0.04397,
#    'rms': 0.02,
#    'gap': 97,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.2 - 14km ESE of Alum Rock, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-121.6848297, 37.3133316, 6.8]},
#   'id': 'nc73804011'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.05999994,
#    'place': '8 km SSW of P?hala, Hawaii',
#    'time': 1667681772830,
#    'updated': 1667681958970,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv73209402',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv73209402&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 65,
#    'net': 'hv',
#    'code': '73209402',
#    'ids': ',hv73209402,',
#    'sources': ',hv,',
#    'types': ',origin,phase-data,',
#    'nst': 38,
#    'dmin': None,
#    'rms': 0.109999999,
#    'gap': 223,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.1 - 8 km SSW of P?hala, Hawaii'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-155.517669677734, 19.1354999542236, 37.0299987792969]},
#   'id': 'hv73209402'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.8,
#    'place': '19 km N of Fishhook, Alaska',
#    'time': 1667681499698,
#    'updated': 1667681609397,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak022e7d9x9t',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak022e7d9x9t&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 50,
#    'net': 'ak',
#    'code': '022e7d9x9t',
#    'ids': ',ak022e7d9x9t,',
#    'sources': ',ak,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.62,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.8 - 19 km N of Fishhook, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-149.2197, 61.9155, 7.5]},
#   'id': 'ak022e7d9x9t'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.3,
#    'place': '52 km W of Anchor Point, Alaska',
#    'time': 1667681330936,
#    'updated': 1667683170040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak022e7d9b0a',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak022e7d9b0a&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 81,
#    'net': 'ak',
#    'code': '022e7d9b0a',
#    'ids': ',us7000imrx,ak022e7d9b0a,',
#    'sources': ',us,ak,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.37,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.3 - 52 km W of Anchor Point, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-152.7506, 59.8588, 95.2]},
#   'id': 'ak022e7d9b0a'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.69,
#    'place': '0km E of Carson, CA',
#    'time': 1667680773120,
#    'updated': 1667784875173,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40129359',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci40129359&format=geojson',
#    'felt': 167,
#    'cdi': 3.7,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 173,
#    'net': 'ci',
#    'code': '40129359',
#    'ids': ',ci40129359,us7000imrw,',
#    'sources': ',ci,us,',
#    'types': ',dyfi,focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 75,
#    'dmin': 0.0384,
#    'rms': 0.27,
#    'gap': 63,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.7 - 0km E of Carson, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-118.2781667, 33.8315, 11.22]},
#   'id': 'ci40129359'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.4,
#    'place': 'Nevada',
#    'time': 1667680373267,
#    'updated': 1667680577762,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00850668',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nn00850668&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 30,
#    'net': 'nn',
#    'code': '00850668',
#    'ids': ',nn00850668,',
#    'sources': ',nn,',
#    'types': ',origin,phase-data,',
#    'nst': 13,
#    'dmin': 0.076,
#    'rms': 0.1258,
#    'gap': 168.38,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.4 - Nevada'},
#   'geometry': {'type': 'Point', 'coordinates': [-117.8775, 38.1797, 6.4]},
#   'id': 'nn00850668'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.4,
#    'place': '35 km SE of Mina, Nevada',
#    'time': 1667678970830,
#    'updated': 1667679166022,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00850667',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nn00850667&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 2,
#    'net': 'nn',
#    'code': '00850667',
#    'ids': ',nn00850667,',
#    'sources': ',nn,',
#    'types': ',origin,phase-data,',
#    'nst': 8,
#    'dmin': 0.092,
#    'rms': 0.1837,
#    'gap': 171.69,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 0.4 - 35 km SE of Mina, Nevada'},
#   'geometry': {'type': 'Point', 'coordinates': [-117.8435, 38.1483, 13.4]},
#   'id': 'nn00850667'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.9,
#    'place': 'Southern Alaska',
#    'time': 1667678875127,
#    'updated': 1667678995346,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak022e7d0iyg',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak022e7d0iyg&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 56,
#    'net': 'ak',
#    'code': '022e7d0iyg',
#    'ids': ',ak022e7d0iyg,',
#    'sources': ',ak,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.35,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.9 - Southern Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-151.1941, 61.8907, 88.9]},
#   'id': 'ak022e7d0iyg'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.32,
#    'place': '7 km SW of Corinne, Utah',
#    'time': 1667678278780,
#    'updated': 1667842494420,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/uu60523412',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uu60523412&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 27,
#    'net': 'uu',
#    'code': '60523412',
#    'ids': ',uu60523412,',
#    'sources': ',uu,',
#    'types': ',origin,phase-data,',
#    'nst': 18,
#    'dmin': 0.1036,
#    'rms': 0.12,
#    'gap': 64,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.3 - 7 km SW of Corinne, Utah'},
#   'geometry': {'type': 'Point', 'coordinates': [-112.176, 41.503, 5.7]},
#   'id': 'uu60523412'},
#  {'type': 'Feature',
#   'properties': {'mag': 4.9,
#    'place': '73 km SSW of Sofifi, Indonesia',
#    'time': 1667677289025,
#    'updated': 1667678061040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000imrl',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000imrl&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 369,
#    'net': 'us',
#    'code': '7000imrl',
#    'ids': ',us7000imrl,',
#    'sources': ',us,',
#    'types': ',origin,phase-data,',
#    'nst': 38,
#    'dmin': 0.655,
#    'rms': 0.77,
#    'gap': 106,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 4.9 - 73 km SSW of Sofifi, Indonesia'},
#   'geometry': {'type': 'Point', 'coordinates': [127.3296, 0.1134, 147.333]},
#   'id': 'us7000imrl'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.85,
#    'place': '7km NW of The Geysers, CA',
#    'time': 1667677047100,
#    'updated': 1667677870559,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73804006',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73804006&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 11,
#    'net': 'nc',
#    'code': '73804006',
#    'ids': ',nc73804006,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 8,
#    'dmin': 0.003782,
#    'rms': 0.02,
#    'gap': 79,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 0.9 - 7km NW of The Geysers, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.8105011, 38.8271675, 1.36]},
#   'id': 'nc73804006'},
#  {'type': 'Feature',
#   'properties': {'mag': -0.4,
#    'place': '36 km WNW of Indian Springs, Nevada',
#    'time': 1667676450757,
#    'updated': 1667702504248,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00850673',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nn00850673&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 0,
#    'net': 'nn',
#    'code': '00850673',
#    'ids': ',nn00850673,',
#    'sources': ',nn,',
#    'types': ',origin,phase-data,',
#    'nst': 7,
#    'dmin': 0.041,
#    'rms': 0.0366,
#    'gap': 147.74,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M -0.4 - 36 km WNW of Indian Springs, Nevada'},
#   'geometry': {'type': 'Point', 'coordinates': [-116.0478, 36.6961, 3.7]},
#   'id': 'nn00850673'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.75,
#    'place': '6km NW of The Geysers, CA',
#    'time': 1667676323070,
#    'updated': 1667677271499,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73804001',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73804001&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 9,
#    'net': 'nc',
#    'code': '73804001',
#    'ids': ',nc73804001,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 9,
#    'dmin': 0.008535,
#    'rms': 0.01,
#    'gap': 142,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 0.8 - 6km NW of The Geysers, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.7993317, 38.8218346, 2.39]},
#   'id': 'nc73804001'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.5,
#    'place': '5 km SE of Cold Springs, Nevada',
#    'time': 1667675885215,
#    'updated': 1667697726457,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00850671',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nn00850671&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 4,
#    'net': 'nn',
#    'code': '00850671',
#    'ids': ',nn00850671,',
#    'sources': ',nn,',
#    'types': ',origin,phase-data,',
#    'nst': 6,
#    'dmin': 0.037,
#    'rms': 0.1211,
#    'gap': 79.45,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 0.5 - 5 km SE of Cold Springs, Nevada'},
#   'geometry': {'type': 'Point', 'coordinates': [-119.9392, 39.6406, 4.8]},
#   'id': 'nn00850671'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.08,
#    'place': '2km SSW of Parkfield, CA',
#    'time': 1667675400280,
#    'updated': 1667675497644,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73803996',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73803996&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 18,
#    'net': 'nc',
#    'code': '73803996',
#    'ids': ',nc73803996,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,',
#    'nst': 13,
#    'dmin': 0.01551,
#    'rms': 0.08,
#    'gap': 202,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.1 - 2km SSW of Parkfield, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-120.4358368, 35.8839989, 5.46]},
#   'id': 'nc73803996'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.58,
#    'place': '38 km NNE of Amboy, Washington',
#    'time': 1667675393930,
#    'updated': 1667756466660,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/uw61893006',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uw61893006&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 5,
#    'net': 'uw',
#    'code': '61893006',
#    'ids': ',uw61893006,',
#    'sources': ',uw,',
#    'types': ',origin,phase-data,',
#    'nst': 14,
#    'dmin': 0.007212,
#    'rms': 0.17,
#    'gap': 75,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 0.6 - 38 km NNE of Amboy, Washington'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.17583333333333, 46.20283333333333, 5.16]},
#   'id': 'uw61893006'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.5,
#    'place': '15 km S of Susitna North, Alaska',
#    'time': 1667675299003,
#    'updated': 1667675462076,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak022e7cf89o',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak022e7cf89o&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 35,
#    'net': 'ak',
#    'code': '022e7cf89o',
#    'ids': ',ak022e7cf89o,',
#    'sources': ',ak,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.36,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.5 - 15 km S of Susitna North, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-149.8798, 62.0237, 34.7]},
#   'id': 'ak022e7cf89o'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.8,
#    'place': '14km NW of Pinnacles, CA',
#    'time': 1667675208590,
#    'updated': 1667704035304,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73803991',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73803991&format=geojson',
#    'felt': 4,
#    'cdi': 2.7,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 122,
#    'net': 'nc',
#    'code': '73803991',
#    'ids': ',nc73803991,us7000imrj,',
#    'sources': ',nc,us,',
#    'types': ',dyfi,focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 79,
#    'dmin': 0.05395,
#    'rms': 0.11,
#    'gap': 54,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.8 - 14km NW of Pinnacles, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-121.2515, 36.629, 9.46]},
#   'id': 'nc73803991'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.4,
#    'place': '55 km S of Whites City, New Mexico',
#    'time': 1667675029253,
#    'updated': 1667838823068,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2022vser',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=tx2022vser&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 89,
#    'net': 'tx',
#    'code': '2022vser',
#    'ids': ',tx2022vser,',
#    'sources': ',tx,',
#    'types': ',origin,phase-data,',
#    'nst': 12,
#    'dmin': 0.01452572935,
#    'rms': 0.3,
#    'gap': 82,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.4 - 55 km S of Whites City, New Mexico'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-104.4091944, 31.6774401, 6.542895508]},
#   'id': 'tx2022vser'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.35,
#    'place': '7km NW of The Geysers, CA',
#    'time': 1667674970410,
#    'updated': 1667676370411,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73803981',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73803981&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 2,
#    'net': 'nc',
#    'code': '73803981',
#    'ids': ',nc73803981,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 9,
#    'dmin': 0.006051,
#    'rms': 0.02,
#    'gap': 79,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 0.4 - 7km NW of The Geysers, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.8026657, 38.8251648, 1.81]},
#   'id': 'nc73803981'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.45,
#    'place': '7km NW of The Geysers, CA',
#    'time': 1667674954890,
#    'updated': 1667689092768,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73803976',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73803976&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 32,
#    'net': 'nc',
#    'code': '73803976',
#    'ids': ',nc73803976,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 27,
#    'dmin': 0.007517,
#    'rms': 0.03,
#    'gap': 33,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.5 - 7km NW of The Geysers, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.8008347, 38.8255005, 1.35]},
#   'id': 'nc73803976'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.5,
#    'place': '20 km WNW of Kalifornsky, Alaska',
#    'time': 1667674858686,
#    'updated': 1667674997166,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak022e7cdlhi',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak022e7cdlhi&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 35,
#    'net': 'ak',
#    'code': '022e7cdlhi',
# ...
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 435,
#    'net': 'us',
#    'code': '7000ilvn',
#    'ids': ',us7000ilvn,usauto7000ilvn,',
#    'sources': ',us,usauto,',
#    'types': ',dyfi,internal-moment-tensor,moment-tensor,origin,phase-data,',
#    'nst': 65,
#    'dmin': 0.724,
#    'rms': 1.28,
#    'gap': 50,
#    'magType': 'mww',
#    'type': 'earthquake',
#    'title': 'M 5.3 - 13 km NNE of Calama, Chile'},
#   'geometry': {'type': 'Point', 'coordinates': [-68.8952, -22.3399, 108.999]},
#   'id': 'us7000ilvn'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.24,
#    'place': '16km WSW of Toms Place, CA',
#    'time': 1667356545040,
#    'updated': 1667366293770,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73802271',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73802271&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 1,
#    'net': 'nc',
#    'code': '73802271',
#    'ids': ',nc73802271,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 11,
#    'dmin': 0.06565,
#    'rms': 0.04,
#    'gap': 303,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 0.2 - 16km WSW of Toms Place, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-118.8553333, 37.5276667, 8.53]},
#   'id': 'nc73802271'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.1,
#    'place': '44 km NW of Toyah, Texas',
#    'time': 1667355541603,
#    'updated': 1667414352272,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2022vlla',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=tx2022vlla&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 68,
#    'net': 'tx',
#    'code': '2022vlla',
#    'ids': ',tx2022vlla,',
#    'sources': ',tx,',
#    'types': ',origin,phase-data,',
#    'nst': 26,
#    'dmin': 0.03992395631,
#    'rms': 0.1,
#    'gap': 60,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.1 - 44 km NW of Toyah, Texas'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-104.1041053, 31.61106665, 7.674047852000001]},
#   'id': 'tx2022vlla'},
#  {'type': 'Feature',
#   'properties': {'mag': 3.3,
#    'place': '73 km N of Charlotte Amalie, U.S. Virgin Islands',
#    'time': 1667355367310,
#    'updated': 1667422379150,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71380493',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=pr71380493&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 168,
#    'net': 'pr',
#    'code': '71380493',
#    'ids': ',pr71380493,',
#    'sources': ',pr,',
#    'types': ',origin,phase-data,',
#    'nst': 14,
#    'dmin': 0.6517,
#    'rms': 0.22,
#    'gap': 271,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 3.3 - 73 km N of Charlotte Amalie, U.S. Virgin Islands'},
#   'geometry': {'type': 'Point', 'coordinates': [-64.997, 19.0065, 21.15]},
#   'id': 'pr71380493'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.28,
#    'place': '1 km ENE of Magna, Utah',
#    'time': 1667354862350,
#    'updated': 1667403788640,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/uu60522622',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uu60522622&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 1,
#    'net': 'uu',
#    'code': '60522622',
#    'ids': ',uu60522622,',
#    'sources': ',uu,',
#    'types': ',origin,phase-data,',
#    'nst': 5,
#    'dmin': 0.06667,
#    'rms': 0.02,
#    'gap': 113,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 0.3 - 1 km ENE of Magna, Utah'},
#   'geometry': {'type': 'Point', 'coordinates': [-112.0815, 40.7123333, 9.25]},
#   'id': 'uu60522622'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.4,
#    'place': None,
#    'time': 1667354669591,
#    'updated': 1667408508740,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00850443',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nn00850443&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 30,
#    'net': 'nn',
#    'code': '00850443',
#    'ids': ',nn00850443,',
#    'sources': ',nn,',
#    'types': ',origin,phase-data,',
#    'nst': 15,
#    'dmin': 0.06,
#    'rms': 0.1504,
#    'gap': 160.09,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.4 - '},
#   'geometry': {'type': 'Point', 'coordinates': [-117.8943, 38.1693, 7.9]},
#   'id': 'nn00850443'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.93,
#    'place': '6 km E of La Parguera, Puerto Rico',
#    'time': 1667354232200,
#    'updated': 1667355027110,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71380488',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=pr71380488&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 57,
#    'net': 'pr',
#    'code': '71380488',
#    'ids': ',pr71380488,',
#    'sources': ',pr,',
#    'types': ',origin,phase-data,',
#    'nst': 6,
#    'dmin': 0.0532,
#    'rms': 0.06,
#    'gap': 185,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.9 - 6 km E of La Parguera, Puerto Rico'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-66.9883333333333, 17.9688333333333, 11.48]},
#   'id': 'pr71380488'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.52,
#    'place': '1km NNW of Larkfield-Wikiup, CA',
#    'time': 1667354209930,
#    'updated': 1667378953045,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73802266',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73802266&format=geojson',
#    'felt': 2,
#    'cdi': 3.4,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 36,
#    'net': 'nc',
#    'code': '73802266',
#    'ids': ',nc73802266,',
#    'sources': ',nc,',
#    'types': ',dyfi,nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 42,
#    'dmin': 0.1237,
#    'rms': 0.14,
#    'gap': 46,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.5 - 1km NNW of Larkfield-Wikiup, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-122.7535, 38.5183333, 5.56]},
#   'id': 'nc73802266'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.99,
#    'place': '8 km W of Pawnee, Oklahoma',
#    'time': 1667353391140,
#    'updated': 1667392202423,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ok2022vljv',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ok2022vljv&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 15,
#    'net': 'ok',
#    'code': '2022vljv',
#    'ids': ',ok2022vljv,',
#    'sources': ',ok,',
#    'types': ',origin,phase-data,',
#    'nst': 46,
#    'dmin': 0.06208781625,
#    'rms': 0.22,
#    'gap': 78,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.0 - 8 km W of Pawnee, Oklahoma'},
#   'geometry': {'type': 'Point', 'coordinates': [-96.89433333, 36.33, 6.23]},
#   'id': 'ok2022vljv'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.29,
#    'place': '11km WNW of Toms Place, CA',
#    'time': 1667353351550,
#    'updated': 1667363651497,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73802261',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73802261&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 1,
#    'net': 'nc',
#    'code': '73802261',
#    'ids': ',nc73802261,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 10,
#    'dmin': 0.01955,
#    'rms': 0.02,
#    'gap': 276,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 0.3 - 11km WNW of Toms Place, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-118.8045, 37.5896667, 4.18]},
#   'id': 'nc73802261'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.97000003,
#    'place': '11 km E of P?hala, Hawaii',
#    'time': 1667352811470,
#    'updated': 1667353004740,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv73204162',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv73204162&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 60,
#    'net': 'hv',
#    'code': '73204162',
#    'ids': ',hv73204162,',
#    'sources': ',hv,',
#    'types': ',origin,phase-data,',
#    'nst': 34,
#    'dmin': None,
#    'rms': 0.159999996,
#    'gap': 164,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.0 - 11 km E of P?hala, Hawaii'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-155.364501953125, 19.2031669616699, 30.1800003051758]},
#   'id': 'hv73204162'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.62,
#    'place': '9km W of Toms Place, CA',
#    'time': 1667352805170,
#    'updated': 1667365934733,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73802246',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73802246&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 40,
#    'net': 'nc',
#    'code': '73802246',
#    'ids': ',nc73802246,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 15,
#    'dmin': 0.03806,
#    'rms': 0.02,
#    'gap': 217,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.6 - 9km W of Toms Place, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-118.7858353, 37.5736656, 6.3]},
#   'id': 'nc73802246'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.9,
#    'place': '60 km WNW of Tatitlek, Alaska',
#    'time': 1667352578602,
#    'updated': 1667352710212,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak022e237xgk',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak022e237xgk&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 56,
#    'net': 'ak',
#    'code': '022e237xgk',
#    'ids': ',ak022e237xgk,',
#    'sources': ',ak,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.89,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.9 - 60 km WNW of Tatitlek, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-147.7242, 61.0563, 113.7]},
#   'id': 'ak022e237xgk'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.3,
#    'place': '23 km SSW of Mammoth, Wyoming',
#    'time': 1667352327400,
#    'updated': 1667401749260,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/uu60522582',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uu60522582&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 26,
#    'net': 'uu',
#    'code': '60522582',
#    'ids': ',uu60522582,',
#    'sources': ',uu,',
#    'types': ',origin,phase-data,',
#    'nst': 14,
#    'dmin': 0.0232,
#    'rms': 0.15,
#    'gap': 107,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.3 - 23 km SSW of Mammoth, Wyoming'},
#   'geometry': {'type': 'Point', 'coordinates': [-110.8181667, 44.7855, 3.91]},
#   'id': 'uu60522582'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.96,
#    'place': '1km WNW of Kensington, CA',
#    'time': 1667352105710,
#    'updated': 1667364252702,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73802241',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73802241&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 14,
#    'net': 'nc',
#    'code': '73802241',
#    'ids': ',nc73802241,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 23,
#    'dmin': 0.01828,
#    'rms': 0.08,
#    'gap': 48,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.0 - 1km WNW of Kensington, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-122.294, 37.916, 4.44]},
#   'id': 'nc73802241'},
#  {'type': 'Feature',
#   'properties': {'mag': -0.07,
#    'place': '24 km SSW of Mammoth, Wyoming',
#    'time': 1667351301800,
#    'updated': 1667403201880,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/uu60522572',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uu60522572&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 0,
#    'net': 'uu',
#    'code': '60522572',
#    'ids': ',uu60522572,',
#    'sources': ',uu,',
#    'types': ',origin,phase-data,',
#    'nst': 7,
#    'dmin': 0.03348,
#    'rms': 0.04,
#    'gap': 182,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M -0.1 - 24 km SSW of Mammoth, Wyoming'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-110.8093333, 44.7721667, 3.27]},
#   'id': 'uu60522572'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.01,
#    'place': '3 km E of Maria Antonia, Puerto Rico',
#    'time': 1667351174970,
#    'updated': 1667352589610,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71380483',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=pr71380483&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 62,
#    'net': 'pr',
#    'code': '71380483',
#    'ids': ',pr71380483,',
#    'sources': ',pr,',
#    'types': ',origin,phase-data,',
#    'nst': 10,
#    'dmin': 0.02235,
#    'rms': 0.12,
#    'gap': 197,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.0 - 3 km E of Maria Antonia, Puerto Rico'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-66.8558333333333, 17.9766666666667, 18.41]},
#   'id': 'pr71380483'},
#  {'type': 'Feature',
#   'properties': {'mag': 4.5,
#    'place': 'Guam region',
#    'time': 1667349750220,
#    'updated': 1667375136006,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000iluv',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000iluv&format=geojson',
#    'felt': 7,
#    'cdi': 3.6,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 314,
#    'net': 'us',
#    'code': '7000iluv',
#    'ids': ',us7000iluv,',
#    'sources': ',us,',
#    'types': ',dyfi,origin,phase-data,',
#    'nst': 19,
#    'dmin': 0.383,
#    'rms': 0.72,
#    'gap': 93,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 4.5 - Guam region'},
#   'geometry': {'type': 'Point', 'coordinates': [144.6595, 13.9158, 185.839]},
#   'id': 'us7000iluv'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.15,
#    'place': '6km NW of The Geysers, CA',
#    'time': 1667349670950,
#    'updated': 1667362872551,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73802231',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc73802231&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 20,
#    'net': 'nc',
#    'code': '73802231',
#    'ids': ',nc73802231,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 22,
#    'dmin': 0.006152,
#    'rms': 0.02,
#    'gap': 41,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.2 - 6km NW of The Geysers, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-122.80867, 38.8173332, 2.99]},
#   'id': 'nc73802231'},
#  ...]

# %%
terremotos_dict = [
                   quake['properties'] for quake in terremotos['features']
]
df = pd.DataFrame(terremotos_dict)
df.head()
# Out:
#     mag                         place           time        updated    tz  \
# 0  2.20  46 km SW of Cantwell, Alaska  1667692676302  1667692812367  None
# 1  0.86    11km SW of The Geysers, CA  1667692595930  1667772555340  None
# 2  3.70        Bali region, Indonesia  1667691998051  1667775336986  None
# 3  0.84     6km NW of The Geysers, CA  1667691880690  1667692510106  None
# 4  1.70   37 km W of Cantwell, Alaska  1667691531222  1667691635832  None
#
#                                                  url  \
# 0  https://earthquake.usgs.gov/earthquakes/eventp...
# 1  https://earthquake.usgs.gov/earthquakes/eventp...
# 2  https://earthquake.usgs.gov/earthquakes/eventp...
# 3  https://earthquake.usgs.gov/earthquakes/eventp...
# 4  https://earthquake.usgs.gov/earthquakes/eventp...
#
#                                               detail  felt  cdi  mmi  ...  \
# 0  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  NaN  ...
# 1  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  NaN  ...
# 2  https://earthquake.usgs.gov/fdsnws/event/1/que...   2.0  3.4  NaN  ...
# 3  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  NaN  ...
# 4  https://earthquake.usgs.gov/fdsnws/event/1/que...   NaN  NaN  NaN  ...
#
#               ids sources                                           types  \
# 0  ,ak022e7f3jny,    ,ak,                             ,origin,phase-data,
# 1    ,nc73804101,    ,nc,  ,nearby-cities,origin,phase-data,scitech-link,
# 2    ,us7000imyj,    ,us,                        ,dyfi,origin,phase-data,
# 3    ,nc73804086,    ,nc,  ,nearby-cities,origin,phase-data,scitech-link,
# 4  ,ak022e7ezgo2,    ,ak,                             ,origin,phase-data,
#
#     nst      dmin   rms    gap magType        type  \
# 0   NaN       NaN  0.31    NaN      ml  earthquake
# 1  30.0  0.052530  0.04  173.0      md  earthquake
# 2  11.0  1.153000  0.87  157.0      ml  earthquake
# 3  10.0  0.007938  0.02   56.0      md  earthquake
# 4   NaN       NaN  2.23    NaN      ml  earthquake
#
#                                   title
# 0  M 2.2 - 46 km SW of Cantwell, Alaska
# 1    M 0.9 - 11km SW of The Geysers, CA
# 2        M 3.7 - Bali region, Indonesia
# 3     M 0.8 - 6km NW of The Geysers, CA
# 4   M 1.7 - 37 km W of Cantwell, Alaska
#
# [5 rows x 26 columns]
